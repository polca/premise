# %%
import premise
from premise import *
import brightway2 as bw
import os
import sys

# %%
# To ensure that the environment you are using does not have the cloned premise code installed in editable mode
# print(premise.__file__)
# this should point to the local github repo, not some library installed in conda

print(premise.__file__)
# Out:
# C:\WORK\premise-witch\premise\__init__.py

# %%
import os,sys
print(os.getcwd())
print(sys.executable)
print(sys.path)
# Out:
# c:\WORK\premise-witch\witch-scenarios
# c:\Users\Ospite EIEE\anaconda3\envs\premise\python.exe
# ['c:\\WORK\\premise-witch', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\python311.zip', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\DLLs', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\Lib', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise', '', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\Lib\\site-packages', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\Lib\\site-packages\\win32', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\Lib\\site-packages\\Pythonwin', 'c:\\Users\\Ospite EIEE\\anaconda3\\envs\\premise\\Lib\\site-packages\\setuptools\\_vendor']

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is B237-8D1E
#
#  Directory of c:\WORK\premise-witch\witch-scenarios
#
# 11/22/2024  02:50 PM    <DIR>          .
# 11/20/2024  09:52 AM    <DIR>          ..
# 11/20/2024  08:25 AM    <DIR>          export
# 11/19/2024  09:36 PM            10,960 premise_witch_test.ipynb
# 11/20/2024  08:25 AM                 0 unlinked.log
# 11/22/2024  02:50 PM         3,793,058 witch_SSP2-Base.csv
#                3 File(s)      3,804,018 bytes
#                3 Dir(s)  178,119,872,512 bytes free

# %%
# My local rep is not appearing in the system path, when I run newdb class it goes to
# c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\premise\new_database.py instead of my repo
# Here I'm manually loading premise from the right path

import importlib.util

spec = importlib.util.spec_from_file_location(
    "premise", "c:/WORK/premise-witch/premise/__init__.py"
)
premise = importlib.util.module_from_spec(spec)
spec.loader.exec_module(premise)

#obs: I had to reinstall premise (from my local repo) module in premise env. Now I need to make sure that all the changes here will be considered

# %%
print(premise.__file__)
# Out:
# C:\WORK\premise-witch\premise\__init__.py

# %%
print("\n".join(sys.path))

# %%
#Path to your local repository
local_repo_path = "c:/WORK/premise-witch"

#Add the local repository to sys.path
if local_repo_path not in sys.path:
    sys.path.insert(0, os.path.abspath(local_repo_path))

# Verify sys.path
print("\n".join(sys.path))

# %%
bw.projects.set_current("premise-witch")

# %%
bw.databases
# Out:
# Databases dictionary with 3 object(s):
# 	biosphere
# 	ecoinvent-3.10-cutoff
# 	ei_cutoff_3.10_witch_SSP2-Base_2050 2024-11-22

# %%
import premise
print(premise.__file__)

# %%
ndb = NewDatabase(
    scenarios=[
        {"model":"witch", "pathway":"SSP2_BAU", "year":2050, "filepath":os.path.join("..", "premise","data", "iam_output_files")},
    ],
    source_db="ecoinvent-3.10-cutoff", 
    source_version="3.10", 
    keep_source_db_uncertainty=False, 
    keep_imports_uncertainty=False, 
    use_absolute_efficiency=True,    
)
# Out:
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 3 object(s):
# 	biosphere
# 	ecoinvent-3.10-cutoff
# 	ei_cutoff_3.10_witch_SSP2-Base_2050 2024-11-22
# premise v.(2, 2, 7)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your bw2 project:                                         |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# +--------------------------------+----------------------------------+
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# +--------------------------------+----------------------------------+
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Reading ..\premise\data\iam_output_files\witch_SSP2_BAU.csv as csv file
# Cannot find variables for cement capture rate.
# Cannot find variables for steel capture rate.
# The following variables are missing from the IAM file:
# +-------------------------------+
# |            Variable           |
# +-------------------------------+
# |            gdp|PPP            |
# |         Emissions|co2         |
# |           population          |
# | Temperature|WITCH|Global Mean |
# +-------------------------------+
# Done!

# %%
ndb.update("electricity")
# Out:
# Processing scenarios for sector 'electricity':   0%| | 0/1 [00:00<?, ?
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'RU') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-AP') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'GB') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'ZA') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'TR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'KR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'HU') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'RoW') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CZ') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-CT') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'EE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CN-GD') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-RJ') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CL') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'GR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'CH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CN-SH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'PE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'TW') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-BR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'NO') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-TN') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-ASCC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-UP') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'LT') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'FI') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-SERC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'IE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CY') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'BR-South-eastern/Mid-western grid') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CA-QC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-WB') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'PL') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014, renewable energy products', 'CH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'PT') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'JP') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-RFC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'SK') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'HR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'AU') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-HICC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-NPCC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'EE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'NL') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CA-BC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-UT') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'AT') has no energy input
# Warning: ('heat and power co-generation, wood chips, 2000 kW, state-of-the-art 2014', 'CH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'ID') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CA-PE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'ES') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'ZA') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'BG') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'TH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 2000 kW', 'CH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'HR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'RU') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'LU') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-WECC') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'DK') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'BG') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'BR-North-eastern grid') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'BE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'MX') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'BR-Northern grid') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'LV') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CA-ON') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-KA') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'IT') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'FR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-MRO') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-MP') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'DE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'SI') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'MY') has no energy input
# Warning: ('heat and power co-generation, wood chips, 2000 kW, state-of-the-art 2014', 'RoW') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-OR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-PB') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'BR-Southern grid') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'US-TRE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CA-AB') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'RoW') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'CA-NS') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'CL') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'UA') has no energy input
# Warning: ('heat and power co-generation, wood chips, 2000 kW', 'RoW') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'SE') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-GJ') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'TZ') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-HR') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'RO') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-MH') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'MT') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'LV') has no energy input
# Warning: ('heat and power co-generation, wood chips, 6667 kW', 'IN-GA') has no energy input
# Warning: ('electricity production, at biomass-fired IGCC power plant, pre, pipeline 200km, storage 1000m', 'RER') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-DL') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-MH') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-BC') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-XZ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-ZJ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-KL') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'US-WECC') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-NT') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-JS') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-GJ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'TH') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'FR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'AT') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'AU') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'SK') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-NF') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'KR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'TZ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-HB') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-GA') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'MX') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-PY') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'US-ASCC') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IT') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-XJ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-NM') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'MY') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'TW') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'US-SERC') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-AB') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-UP') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-SA') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-TN') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-SX') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-GZ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-KA') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-TR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'LU') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'RU') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'US-MRO') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'RoW') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'BR-North-eastern grid') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-TJ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-DN') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-QH') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-GD') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'PT') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-MB') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'PE') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-JX') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-AS') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-NX') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-SD') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-GX') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-MP') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'FI') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-GS') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-LN') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'GB') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-JL') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-FJ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CZ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-RJ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IE') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'SI') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-YN') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-HL') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-BJ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-HR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-HE') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-NB') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'US-RFC') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'UA') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-AH') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'NO') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'ID') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'BR-South-eastern/Mid-western grid') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'JP') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-PE') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-CQ') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'HR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'DE') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'BG') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-HA') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-SC') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'US-TRE') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'US-NPCC') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-HN') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'TR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'SA') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'BE') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'GR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-NS') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'NL') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-SK') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CL') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'AR') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CO') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'IN-AP') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-HU') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CA-ON') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'ES') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'HU') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'RO') has no energy input
# Warning: ('electricity production, natural gas, conventional power plant', 'CN-SH') has no energy input
# Processing scenarios for sector 'electricity': 100%|█| 1/1 [01:24<00:0
# Done!

# %%
ndb.update()
# Out:
# Processing scenarios for all sectors:   0%|     | 0/1 [00:00<?, ?it/s]
# Function to update biomass already applied to scenario.
# Function to update electricity already applied to scenario.
# Function to update dac already applied to scenario.
# Function to update cement already applied to scenario.
# Function to update steel already applied to scenario.
# Initial energy consumption for hydrogen, from electrolysis, PEM in World is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'World', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1.40403598143152}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'World', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in brazil is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'brazil', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0800383409636159}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'brazil', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in canada is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'canada', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0020601362747921}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'canada', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in ccasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'ccasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0040436817999091}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'ccasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in china is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'china', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.596834787094165}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'china', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in eu27 is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'eu27', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.190051099831585}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'eu27', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in india is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'india', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0232640353573415}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'india', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in indonesia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'indonesia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0001467053881806}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'indonesia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in japan is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'japan', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0091456876316042}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'japan', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in korea is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'korea', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0016782575437151}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'korea', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in laca is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'laca', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.134068602387978}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'laca', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in mena is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'mena', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.048774383546526}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'mena', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in mexico is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'mexico', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0122945831928835}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'mexico', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in oceania is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'oceania', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0271177545503391}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'oceania', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in othereurope is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'othereurope', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0295678380007767}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'othereurope', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in sasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'sasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.47324013401196e-08}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'sasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in seasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'seasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0253184946861711}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'seasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in southafrica is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'southafrica', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0289676903849467}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'southafrica', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in ssa is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'ssa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.87217482009838e-08}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'ssa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in te is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'te', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0450205819251264}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'te', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, PEM in usa is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'amount': 1.0, 'location': 'usa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 30 bar', 'uncertainty type': 0, 'product': 'hydrogen, gaseous, 30 bar', 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.145643247417713}
# {'name': 'hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 30 bar', 'location': 'usa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in World is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'World', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'World', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in brazil is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'brazil', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'brazil', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in canada is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'canada', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'canada', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in ccasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'ccasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'ccasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in china is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'china', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'china', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in eu27 is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'eu27', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'eu27', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in india is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'india', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'india', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in indonesia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'indonesia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'indonesia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in japan is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'japan', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'japan', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in korea is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'korea', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'korea', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in laca is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'laca', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'laca', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in mena is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'mena', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'mena', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in mexico is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'mexico', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'mexico', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in oceania is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'oceania', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'oceania', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in othereurope is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'othereurope', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'othereurope', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in sasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'sasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'sasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in seasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'seasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'seasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in southafrica is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'southafrica', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'southafrica', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in ssa is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'ssa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'ssa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in te is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'te', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'te', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, AEC in usa is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'usa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 20 bar', 'product': 'hydrogen, gaseous, 20 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 20 bar, from AEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 20 bar', 'location': 'usa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
# C:\WORK\premise-witch\premise\fuels.py:613: RuntimeWarning: divide by zero encountered in scalar divide
#   scaling_factor = new_energy_use / initial_energy_use
# Initial energy consumption for hydrogen, from electrolysis, SOEC in World is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'World', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 7.2e-14}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'World', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in brazil is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'brazil', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'brazil', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in canada is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'canada', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'canada', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in ccasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'ccasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'ccasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in china is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'china', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'china', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in eu27 is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'eu27', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'eu27', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in india is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'india', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'india', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in indonesia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'indonesia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'indonesia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in japan is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'japan', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'japan', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in korea is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'korea', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'korea', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in laca is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'laca', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'laca', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in mena is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'mena', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'mena', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in mexico is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'mexico', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'mexico', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in oceania is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'oceania', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'oceania', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in othereurope is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'othereurope', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'othereurope', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in sasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'sasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'sasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in seasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'seasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'seasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in southafrica is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'southafrica', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'southafrica', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in ssa is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'ssa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'ssa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in te is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'te', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'te', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from electrolysis, SOEC in usa is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'amount': 1.0, 'location': 'usa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 1 bar', 'product': 'hydrogen, gaseous, 1 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, gaseous, 1 bar, from SOEC electrolysis, from grid electricity', 'product': 'hydrogen, gaseous, 1 bar', 'location': 'usa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from solar in World is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'amount': 1.0, 'location': 'World', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 25 bar', 'product': 'hydrogen, gaseous, 25 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'product': 'hydrogen, gaseous, 25 bar', 'location': 'World', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from solar in brazil is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'amount': 1.0, 'location': 'brazil', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 25 bar', 'product': 'hydrogen, gaseous, 25 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'product': 'hydrogen, gaseous, 25 bar', 'location': 'brazil', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from solar in canada is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'amount': 1.0, 'location': 'canada', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 25 bar', 'product': 'hydrogen, gaseous, 25 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'product': 'hydrogen, gaseous, 25 bar', 'location': 'canada', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from solar in ccasia is None.
# List of exchanges:
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'amount': 1.0, 'location': 'ccasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, 25 bar', 'product': 'hydrogen, gaseous, 25 bar', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 1}
# {'name': 'hydrogen production, gaseous, 25 bar, from thermochemical water splitting, at solar tower', 'product': 'hydrogen, gaseous, 25 bar', 'location': 'ccasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from solar in china is None.
# List of exchanges:
# ...
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'brazil', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in canada is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'canada', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'canada', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in ccasia is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'ccasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'ccasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in china is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'china', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 0.0126745232285602}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'china', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in eu27 is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'eu27', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'eu27', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in india is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'india', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'india', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in indonesia is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'indonesia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'indonesia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in japan is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'japan', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'japan', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in korea is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'korea', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'korea', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in laca is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'laca', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'laca', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in mena is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'mena', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'mena', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in mexico is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'mexico', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'mexico', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in oceania is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'oceania', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'oceania', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in othereurope is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'othereurope', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'othereurope', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in sasia is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'sasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'sasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in seasia is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'seasia', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'seasia', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in southafrica is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'southafrica', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'southafrica', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in ssa is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'ssa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'ssa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in te is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'te', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'te', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# Initial energy consumption for hydrogen, from natural gas, with CCS in usa is None.
# List of exchanges:
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'amount': 1.0, 'database': 'Car db', 'location': 'usa', 'unit': 'kilogram', 'type': 'production', 'reference product': 'hydrogen, gaseous, low pressure', 'product': 'hydrogen, gaseous, low pressure', 'uncertainty type': 0, 'loc': 1, 'scale': nan, 'shape': nan, 'minimum': nan, 'maximum': nan, 'production volume': 3.6e-15}
# {'name': 'hydrogen production, steam methane reforming, with CCS', 'product': 'hydrogen, gaseous, low pressure', 'location': 'usa', 'unit': 'kilogram', 'type': 'technosphere', 'amount': 1.0}
#
# ---> MAJOR anomalies found during fuels update: check the change report.
# Processing scenarios for all sectors:   0%|     | 0/1 [03:26<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 ndb.update()
#
# File C:\WORK\premise-witch\premise\new_database.py:975, in NewDatabase.update(self, sectors)
#     973 update_func = sector_update_methods[sector]["func"]
#     974 fixed_args = sector_update_methods[sector]["args"]
# --> 975 scenario = update_func(scenario, *fixed_args)
#     977 if "applied functions" not in scenario:
#     978     scenario["applied functions"] = []
#
# File C:\WORK\premise-witch\premise\transport.py:52, in _update_vehicles(scenario, vehicle_type, version, system_model)
#      49 else:
#      50     raise ValueError("Unknown vehicle type.")
# ---> 52 trspt = Transport(
#      53     database=scenario["database"],
#      54     year=scenario["year"],
#      55     model=scenario["model"],
#      56     pathway=scenario["pathway"],
#      57     iam_data=scenario["iam data"],
#      58     version=version,
#      59     system_model=system_model,
#      60     vehicle_type=vehicle_type,
#      61     relink=False,
#      62     has_fleet=has_fleet,
#      63     index=scenario.get("index"),
#      64 )
#      66 scenario["database"] = trspt.database
#      67 scenario["cache"] = trspt.cache
#
# File C:\WORK\premise-witch\premise\transport.py:397, in Transport.__init__(self, database, iam_data, model, pathway, year, version, system_model, relink, vehicle_type, has_fleet, index)
#     394         print(f"Vehicle map is empty for {self.vehicle_type}.")
#     396 if self.has_fleet:
# --> 397     fleet_datasets = self.create_vehicle_markets()
#     398     self.database.extend(fleet_datasets)
#     399     self.add_to_index(fleet_datasets)
#
# File C:\WORK\premise-witch\premise\transport.py:509, in Transport.create_vehicle_markets(self)
#     493 for dataset in ws.get_many(
#     494     self.database,
#     495     ws.doesnt_contain_any("name", ["freight, lorry"]),
#     496     ws.exclude(ws.equals("unit", "ton kilometer")),
#     497 ):
#     498     for exc in ws.technosphere(
#     499         dataset,
#     500         ws.either(
#    (...)
#     506         ws.equals("unit", "ton kilometer"),
#     507     ):
# --> 509         new_name = self.mapping["truck"]["old_trucks"][exc["name"]][
#     510             self.model
#     511         ]
#     512         new_loc = self.geo.ecoinvent_to_iam_location(dataset["location"])
#     514         if (new_name, new_loc) in list_created_vehicles:
#
# KeyError: 'witch'

# %%
ndb.write_db_to_brightway()
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# Writing activities to SQLite3 database:
# 0% [##############                ] 100% | ETA: 00:00:29
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 ndb.write_db_to_brightway()
#
# File C:\WORK\premise-witch\premise\new_database.py:1117, in NewDatabase.write_db_to_brightway(self, name)
#    1109         scenario["database"] = pickle.loads(pickle.dumps(self.database, -1))
#    1111     _prepare_database(
#    1112         scenario=scenario,
#    1113         db_name=name[s],
#    1114         original_database=self.database,
#    1115         biosphere_name=self.biosphere_name,
#    1116     )
# -> 1117     write_brightway_database(
#    1118         scenario["database"],
#    1119         name[s],
#    1120     )
#    1122     end_of_process(scenario)
#    1124 delete_all_pickles()
#
# File C:\WORK\premise-witch\premise\brightway2.py:48, in write_brightway_database(data, name)
#      46 link_internal(data)
#      47 check_internal_linking(data)
# ---> 48 BW2Importer(name, data).write_database()
#
# File C:\WORK\premise-witch\premise\brightway2.py:36, in BW2Importer.write_database(self)
#      34     print(f"Database {self.db_name} already exists: it will be overwritten.")
#      35     del databases[self.db_name]
# ---> 36 super().write_database()
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\bw2io\importers\base_lci.py:273, in LCIImporter.write_database(self, data, delete_existing, backend, activate_parameters, **kwargs)
#     270 self.write_database_parameters(activate_parameters, delete_existing)
#     272 existing.update(data)
# --> 273 db.write(existing)
#     275 if activate_parameters:
#     276     self._write_activity_parameters(activity_parameters)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\bw2data\project.py:358, in writable_project(wrapped, instance, args, kwargs)
#     356 if projects.read_only:
#     357     raise ReadOnlyProject(READ_ONLY_PROJECT)
# --> 358 return wrapped(*args, **kwargs)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\bw2data\backends\peewee\database.py:260, in SQLiteBackend.write(self, data, process)
#     258 if data:
#     259     try:
# --> 260         self._efficient_write_many_data(data)
#     261     except:
#     262         # Purge all data from database, then reraise
#     263         self.delete(warn=False)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\bw2data\backends\peewee\database.py:204, in SQLiteBackend._efficient_write_many_data(self, data, indices)
#     197     self.pbar = pyprind.ProgBar(
#     198         len(data),
#     199         title="Writing activities to SQLite3 database:",
#     200         monitor=True
#     201     )
#     203 for index, (key, ds) in enumerate(data.items()):
# --> 204     exchanges, activities = self._efficient_write_dataset(
#     205         index, key, ds, exchanges, activities
#     206     )
#     208 if not getattr(config, "is_test", None):
#     209     print(self.pbar)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\bw2data\backends\peewee\database.py:168, in SQLiteBackend._efficient_write_dataset(self, index, key, ds, exchanges, activities)
#     162     # Query gets passed as INSERT INTO x VALUES ('?', '?'...)
#     163     # SQLite3 has a limit of 999 variables,
#     164     # So 6 fields * 125 is under the limit
#     165     # Otherwise get the following:
#     166     # peewee.OperationalError: too many SQL variables
#     167     if len(exchanges) > 125:
# --> 168         ExchangeDataset.insert_many(exchanges).execute()
#     169         exchanges = []
#     171 ds = {k: v for k, v in ds.items() if k != "exchanges"}
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\peewee.py:1966, in database_required.<locals>.inner(self, database, *args, **kwargs)
#    1963 if not database:
#    1964     raise InterfaceError('Query must be bound to a database in order '
#    1965                          'to call "%s".' % method.__name__)
# -> 1966 return method(self, database, *args, **kwargs)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\peewee.py:2037, in BaseQuery.execute(self, database)
#    2035 @database_required
#    2036 def execute(self, database):
# -> 2037     return self._execute(database)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\peewee.py:2842, in Insert._execute(self, database)
#    2840     self._returning = (self.table._primary_key,)
#    2841 try:
# -> 2842     return super(Insert, self)._execute(database)
#    2843 except self.DefaultValuesException:
#    2844     pass
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\peewee.py:2555, in _WriteQuery._execute(self, database)
#    2553     cursor = self.execute_returning(database)
#    2554 else:
# -> 2555     cursor = database.execute(self)
#    2556 return self.handle_result(database, cursor)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\peewee.py:3254, in Database.execute(self, query, commit, **context_options)
#    3252 ctx = self.get_sql_context(**context_options)
#    3253 sql, params = ctx.sql(query).query()
# -> 3254 return self.execute_sql(sql, params)
#
# File c:\Users\Ospite EIEE\anaconda3\envs\premise\Lib\site-packages\peewee.py:3246, in Database.execute_sql(self, sql, params, commit)
#    3244 with __exception_wrapper__:
#    3245     cursor = self.cursor()
# -> 3246     cursor.execute(sql, params or ())
#    3247 return cursor
#
# KeyboardInterrupt:

# %%
bw.databases
# Out:
# Databases dictionary with 3 object(s):
# 	biosphere
# 	ecoinvent-3.10-cutoff
# 	ei_cutoff_3.10_witch_SSP2-Base_2050 2024-11-22
