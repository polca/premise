# %%
from premise import *
import bw2data, bw2io, bw2calc
#bw2data.projects.set_current("bw25_ei310")
bw2data.projects.set_current("ecoinvent-3.12-cutoff")
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# 18:51:42+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.

# %%
scenario = {"model": "remind", "pathway": "SSP2-NPi"}
ndb = TrailsDataPackage(
        scenario = scenario,
        source_db="ecoinvent-3.12-cutoff",
        source_version="3.12",
        key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
        biosphere_name="biosphere3",
        use_absolute_efficiency=True,
        #years=[2005,]
)
# Out:
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# Cannot find the IAM scenario file at /Users/romain/GitHub/premise/premise/data/iam_output_files/remind_SSP2-NPi. Will check online.
# premise v.(2, 3, 7)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# remind_SSP2-NPi.csv not found locally. Downloading...
# remind_SSP2-NPi.csv: 13.3MB [00:01, 11.8MB/s]
# remind_SSP2-NPi.csv downloaded successfully.
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Found file: remind_SSP2-NPi
# Reading remind_SSP2-NPi as CSV file
# Done!

# %%
ndb.create_datapackage()
# Out:
# Processing scenarios for all sectors: 100%|█| 11/11 [21:18<00:00, 116.
# Done!
#
# Write new database(s) to matrix.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2005.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2015.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2025.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2035.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2045.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2055.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2065.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2075.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2085.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2095.
# Running all checks...
# Minor anomalies found: check the change report.
# Matrices saved in /Users/romain/GitHub/premise/dev/trails_temp/inventories/remind/SSP2-NPi/2100.
# Generate scenario report.
# Report saved under /Users/romain/GitHub/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/GitHub/premise/dev/export/change reports/.
# Reordering matrices to global index spaces...
# Trails data package saved at /Users/romain/GitHub/premise/dev/trails_2026-03-03.zip
