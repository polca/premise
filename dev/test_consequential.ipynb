# %%
from premise import *
import bw2data, bw2io, bw2calc
bw2data.projects.set_current("ei39")

# %%
args = {
    "range time": 2,
    "duration": False,
    "foresight": False,
    "lead time": True,
    "capital replacement rate": False,
    "measurement": 0,
    "weighted slope start": 0.75,
    "weighted slope end": 1.00
}

# %%
scenaria=[
    {"model":"remind","pathway":"SSP2-Base","year":2032},
]

# %%
#clear_cache()
ndb = NewDatabase(
    scenarios=scenaria,
    source_db="ecoinvent 3.9.1 consequential", # <-- Must point to the consequential database.
    source_version="3.9.1",
    source_type="brightway",
    #source_file_path="/home/misc/Documents/ecoinvent 3.9.1_consequential_ecoSpold02/datasets/",
    key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
    system_model="consequential", # <-- Must specify "consequential"
    system_args=args, # Optional. Arguments.
    quiet=True,
)
#ndb.update_all()
#ndb.write_db_to_brightway(names)
# Out:
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
#
# Summary of the electricity marginal market mixes:
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | Region | Measurement method | Foresight? | Duration | Avg. start year | Avg. end year | Avg. capital repl. rate | Volume change |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CAZ   |         0          |   False    |  False   |       2033      |      2037     |          -0.01          |      0.02     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CHA   |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |      0.56     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  EUR   |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |      0.1      |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  IND   |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |      0.45     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  JPN   |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |     -0.01     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  LAM   |         0          |   False    |  False   |       2033      |      2037     |          -0.01          |      0.35     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  MEA   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.43     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  NEU   |         0          |   False    |  False   |       2033      |      2037     |          -0.01          |      0.02     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  OAS   |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |      0.46     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  REF   |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |      0.24     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  SSA   |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |      0.31     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  USA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.08     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | World  |         0          |   False    |  False   |       2033      |      2037     |          -0.02          |      3.06     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
#
# Summary of the petrol marginal market mixes:
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | Region | Measurement method | Foresight? | Duration | Avg. start year | Avg. end year | Avg. capital repl. rate | Volume change |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CAZ   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.08     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CHA   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.25     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  EUR   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.14     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  IND   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.32     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  JPN   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.02     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  LAM   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.34     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  MEA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.07     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  NEU   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.02     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  OAS   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.31     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  REF   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.27     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  SSA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.26     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  USA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.65     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | World  |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      2.24     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
#
# Summary of the diesel marginal market mixes:
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | Region | Measurement method | Foresight? | Duration | Avg. start year | Avg. end year | Avg. capital repl. rate | Volume change |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CAZ   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.01     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CHA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.26     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  EUR   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.03     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  IND   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.42     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  JPN   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      -0.0     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  LAM   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.26     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  MEA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.17     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  NEU   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.02     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  OAS   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.3      |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  REF   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.21     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  SSA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.27     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  USA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.17     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | World  |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      2.07     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
#
# Summary of the gas marginal market mixes:
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | Region | Measurement method | Foresight? | Duration | Avg. start year | Avg. end year | Avg. capital repl. rate | Volume change |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CAZ   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |     -0.02     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CHA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.05     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  EUR   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |     -0.16     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  IND   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.1      |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  JPN   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |     -0.02     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  LAM   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.1      |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  MEA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.1      |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  NEU   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.01     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  OAS   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.09     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  REF   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.04     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  SSA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.13     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  USA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |     -0.16     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | World  |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.28     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
#
# Summary of the hydrogen marginal market mixes:
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | Region | Measurement method | Foresight? | Duration | Avg. start year | Avg. end year | Avg. capital repl. rate | Volume change |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CAZ   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.01     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  CHA   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.05     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  EUR   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.03     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  IND   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.04     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  JPN   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.01     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  LAM   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.04     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  MEA   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.08     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  NEU   |         0          |   False    |  False   |       2032      |      2036     |          -0.03          |      0.01     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  OAS   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.05     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  REF   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.05     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  SSA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.03     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# |  USA   |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.05     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# | World  |         0          |   False    |  False   |       2033      |      2037     |          -0.03          |      0.46     |
# +--------+--------------------+------------+----------+-----------------+---------------+-------------------------+---------------+
# Done!

# %%
ndb.update()
# Out:
# `update()` will skip the following sectors: 'buses', 'cars', 'two_wheelers'.
# If you want to update these sectors, please run them separately afterwards.
# Updating: external:  90%|████████████▌ | 9/10 [01:49<00:12, 12.15s/it]
# External scenarios (datapackages) are not provided. Skipped.
# Done!

# %%
ndb.write_db_to_brightway("test14")
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Anomalies found: check the change report.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:15
# Title: Writing activities to SQLite3 database:
#   Started: 02/13/2024 10:16:03
#   Finished: 02/13/2024 10:16:19
#   Total time elapsed: 00:00:15
#   CPU %: 95.70
#   Memory %: 9.53
# Created database: test14
# Generate scenario report.
# Report saved under /Users/romain/Github/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/Github/premise/dev.
