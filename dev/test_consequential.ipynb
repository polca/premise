# %%
from premise import *
import bw2data, bw2io, bw2calc
bw2data.projects.set_current("ei39")

# %%
args = {
    "range time": 2,
    "duration": False,
    "foresight": False,
    "lead time": True,
    "capital replacement rate": False,
    "measurement": 0,
    "weighted slope start": 0.75,
    "weighted slope end": 1.00
}

# %%
scenaria=[
    {"model":"remind","pathway":"SSP1-Base","year":2032},
]

# %%
#clear_cache()
ndb = NewDatabase(
    scenarios=scenaria,
    source_db="ecoinvent 3.9.1 consequential", # <-- Must point to the consequential database.
    source_version="3.9.1",
    source_type="brightway",
    #source_file_path="/home/misc/Documents/ecoinvent 3.9.1_consequential_ecoSpold02/datasets/",
    key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
    system_model="consequential", # <-- Must specify "consequential"
    system_args=args, # Optional. Arguments.
    quiet=True,
)
#ndb.update_all()
#ndb.write_db_to_brightway(names)
# Out:
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
#
# Summary of the electricity marginal market mixes:
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | Region | Measurement method | Start | End  | Avg start | Avg end | Avg lifetime | Avg capital repl. rate | Volume change |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CAZ   |         0          |  2033 | 2037 |    2033   |   2037  |      82      |         -0.01          |     -0.02     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CHA   |         0          |  2033 | 2037 |    2033   |   2037  |      52      |         -0.02          |      0.48     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  EUR   |         0          |  2033 | 2037 |    2033   |   2037  |      43      |         -0.02          |     -0.01     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  IND   |         0          |  2033 | 2037 |    2033   |   2037  |      39      |         -0.03          |      0.54     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  JPN   |         0          |  2034 | 2038 |    2034   |   2038  |      49      |         -0.02          |     -0.05     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  LAM   |         0          |  2033 | 2037 |    2033   |   2037  |      72      |         -0.01          |      0.35     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  MEA   |         0          |  2032 | 2036 |    2032   |   2036  |      37      |         -0.03          |      0.26     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  NEU   |         0          |  2033 | 2037 |    2033   |   2037  |      82      |         -0.01          |      -0.0     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  OAS   |         0          |  2033 | 2037 |    2033   |   2037  |      47      |         -0.02          |      0.43     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  REF   |         0          |  2033 | 2037 |    2033   |   2037  |      53      |         -0.02          |      0.17     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  SSA   |         0          |  2033 | 2037 |    2033   |   2037  |      53      |         -0.02          |      0.28     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  USA   |         0          |  2033 | 2037 |    2033   |   2037  |      40      |         -0.02          |     -0.02     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | World  |         0          |  2033 | 2037 |    2033   |   2037  |      49      |         -0.02          |      2.34     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
#
# Summary of the petrol marginal market mixes:
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | Region | Measurement method | Start | End  | Avg start | Avg end | Avg lifetime | Avg capital repl. rate | Volume change |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CAZ   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.01     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CHA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.14     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  EUR   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      -0.0     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  IND   |         0          |  2032 | 2036 |    2032   |   2036  |      34      |         -0.03          |      0.17     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  JPN   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.03     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  LAM   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.13     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  MEA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.04     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  NEU   |         0          |  2032 | 2036 |    2032   |   2036  |      35      |         -0.03          |      0.04     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  OAS   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.16     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  REF   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.08     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  SSA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.27     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  USA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.31     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | World  |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      1.03     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
#
# Summary of the diesel marginal market mixes:
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | Region | Measurement method | Start | End  | Avg start | Avg end | Avg lifetime | Avg capital repl. rate | Volume change |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CAZ   |         0          |  2032 | 2036 |    2032   |   2036  |      35      |         -0.03          |     -0.05     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CHA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.13     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  EUR   |         0          |  2033 | 2037 |    2033   |   2037  |      34      |         -0.03          |     -0.11     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  IND   |         0          |  2032 | 2036 |    2032   |   2036  |      34      |         -0.03          |      0.27     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  JPN   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      -0.0     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  LAM   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.12     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  MEA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.04     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  NEU   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.04     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  OAS   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.18     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  REF   |         0          |  2032 | 2036 |    2032   |   2036  |      35      |         -0.03          |      0.04     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  SSA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.27     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  USA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.07     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | World  |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.81     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
#
# Summary of the gas marginal market mixes:
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | Region | Measurement method | Start | End  | Avg start | Avg end | Avg lifetime | Avg capital repl. rate | Volume change |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CAZ   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.04     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CHA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.02     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  EUR   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.21     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  IND   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.07     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  JPN   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.03     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  LAM   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.0      |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  MEA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.08     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  NEU   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      -0.0     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  OAS   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.0      |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  REF   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.07     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  SSA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.07     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  USA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.27     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | World  |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |     -0.55     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
#
# Summary of the hydrogen marginal market mixes:
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | Region | Measurement method | Start | End  | Avg start | Avg end | Avg lifetime | Avg capital repl. rate | Volume change |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CAZ   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.01     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  CHA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.07     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  EUR   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.02     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  IND   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.02     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  JPN   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.01     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  LAM   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.03     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  MEA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.03     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  NEU   |         0          |  2032 | 2036 |    2032   |   2036  |      35      |         -0.03          |      0.0      |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  OAS   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.03     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  REF   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.02     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  SSA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.01     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# |  USA   |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.03     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# | World  |         0          |  2033 | 2037 |    2033   |   2037  |      35      |         -0.03          |      0.28     |
# +--------+--------------------+-------+------+-----------+---------+--------------+------------------------+---------------+
# Done!

# %%
ndb.update()
# Out:
# `update()` will skip the following sectors: 'buses', 'cars', 'two_wheelers'.
# If you want to update these sectors, please run them separately afterwards.
# Updating: external:  90%|████████████▌ | 9/10 [01:49<00:12, 12.15s/it]
# External scenarios (datapackages) are not provided. Skipped.
# Done!

# %%
ndb.write_db_to_brightway("test14")
# Out:
# Write new database(s) to Brightway.
# Running all checks...
# Anomalies found: check the change report.
# Writing activities to SQLite3 database:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:15
# Title: Writing activities to SQLite3 database:
#   Started: 02/13/2024 10:16:03
#   Finished: 02/13/2024 10:16:19
#   Total time elapsed: 00:00:15
#   CPU %: 95.70
#   Memory %: 9.53
# Created database: test14
# Generate scenario report.
# Report saved under /Users/romain/Github/premise/dev/export/scenario_report.
# Generate change report.
# Report saved under /Users/romain/Github/premise/dev.
