# %%
from premise import *
import bw2data
import bw2io as bi

bw2data.projects.set_current('premise')
print(bw2data.databases)

ei = bi.SingleOutputEcospold2Importer(dirpath=r'ecoinvent 3.11_cutoff_ecoSpold02', db_name='ecoinvent_3.11_cutoff') #recommendation for consistent databases naming: database name (ecoinvent), version number, system model
ei.apply_strategies() #fixing some issues when ecoinvent and brightway have to talk together by going through all datasets and manipulating them in a specific way
ei.statistics() #checking if everything worked out with strategies and linking
ei.write_database() #save the database to our hard drive

exit()

ndb = NewDatabase(
    scenarios=[
        {"model":"gcam", "pathway":"ssp24p5tol5", "year":2050},
    ],
    source_db="ecoinvent-3.11-cutoff", # <-- name of the database in the BW2 project. Must be a string.
    source_version="3.11", # <-- version of ecoinvent. Can be "3.8", "3.9" or "3.10". Must be a string.
    key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=', # <-- decryption key
    # to be requested from the library maintainers if you want ot use default scenarios included in `premise`
    keep_source_db_uncertainty=False, # False by default, set to True if you want to keep ecoinvent's uncertainty data
    keep_imports_uncertainty=False, # False by default, set to True if you want to keep the uncertainty data of the additional inventories
    use_absolute_efficiency=True, # False by default, set to True if you want to use the IAM's absolute efficiencies
)
# Out:
# Databases dictionary with 0 objects
# premise requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 0 objects
