# %% [markdown]
# # LCIA and contribution analysis of European hydrogen markets
#
# This notebook compares the **sector-specific low-pressure gaseous hydrogen markets** available for Europe with one generic European hydrogen market. It uses the same Brightway project and prospective database as `LCIA_contribution_analysis_hydrogen_transport.ipynb`.
#
# The functional unit is **1 kg of hydrogen, gaseous, low pressure**. All unweighted EF 3.1 midpoint categories are calculated together with the premise IPCC 2021 GWP100 method that characterizes hydrogen emissions and aggregate renewable/non-renewable Cumulative Energy Demand (CED), followed by relative comparisons and upstream process contribution analysis.

# %%
import os

os.environ["MKL_THREADING_LAYER"] = "TBB"

# %% [markdown]
# ## 1. Geography and comparison design
#
# The requested generic comparator is selected at exact ecoinvent location `RER`. In this prospective database, generated sector-specific markets use the IAM region `EUR`, not `RER`. The selection code first looks at `RER` and then uses the explicit `EUR` fallback, printing every selected key and location.
#
# One baseline is retained: **Generic (RER)**, the requested European generic-market comparator. No second generic `EUR` market is included because it has the same modeled supply-chain results in this database.
#
# Only sector markets actually present in the configured database are analyzed. `premise` creates a sector market only where the modeled sector has positive hydrogen demand.

# %%
from pathlib import Path
import math
import warnings

import bw2data as bd
import bw2calc as bc
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from premise_gwp import add_premise_gwp

pd.set_option("display.max_colwidth", 140)
plt.style.use("seaborn-v0_8-whitegrid")
plt.rcParams.update({
    "font.size": 12,
    "axes.titlesize": 15,
    "axes.labelsize": 13,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "legend.fontsize": 11,
    "legend.title_fontsize": 12,
    "figure.titlesize": 18,
})
# Out:
# 17:13:52+0200 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.

# %%
list(bd.databases)
# Out:
# []

# %% [markdown]
# ## 2. Configuration
#
# The project and database exactly match the source notebook. Change only these constants when deliberately applying the workflow to another prospective database.

# %%
PROJECT = "ecoinvent-3.12-cutoff"
DATABASE = "ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full"
GENERIC_MARKET_NAME = "market for hydrogen, gaseous, low pressure"
REFERENCE_PRODUCT = "hydrogen, gaseous, low pressure"
UNIT = "kilogram"
FUNCTIONAL_UNIT_KG = 1.0
TARGET_LOCATION = "RER"
SECTOR_LOCATION_FALLBACKS = ("EUR", "WEU")
TOP_N_PROCESSES = 10
PREMISE_GWP_METHOD = ("IPCC 2021", "climate change", "GWP 100a, incl. H")
CED_METHODS = [
    ("Cumulative Energy Demand (CED)", "energy resources: non-renewable", "energy content (HHV)"),
    ("Cumulative Energy Demand (CED)", "energy resources: renewable", "energy content (HHV)"),
]

EXPECTED_SECTOR_MARKETS = {
    "Transport": f"{GENERIC_MARKET_NAME}, for transport",
    "Chemicals": f"{GENERIC_MARKET_NAME}, for chemicals",
    "Steel": f"{GENERIC_MARKET_NAME}, for steel",
    "Cement": f"{GENERIC_MARKET_NAME}, for cement",
    "Heating": f"{GENERIC_MARKET_NAME}, for heating",
    "Other end uses": f"{GENERIC_MARKET_NAME}, for other end uses",
}

# %% [markdown]
# ## 3. Open the project and select European market datasets
#
# Selection requires exact activity name, reference product, unit, and location. Duplicate exact matches are treated as errors rather than chosen arbitrarily.

# %%
bd.projects.set_current(PROJECT)

# Import/refresh the premise climate methods before selecting LCIA methods.
# PREMISE_GWP_METHOD includes the characterization factor for hydrogen emissions to air.
add_premise_gwp()
if PREMISE_GWP_METHOD not in bd.methods:
    raise LookupError(f"premise_gwp did not install the expected method: {PREMISE_GWP_METHOD}")
if DATABASE not in bd.databases:
    available = "\n".join(f"  - {name}" for name in bd.databases)
    raise KeyError(f"Database {DATABASE!r} is unavailable. Available databases:\n{available}")

database = bd.Database(DATABASE)
print(f"Project:  {bd.projects.current}")
print(f"Database: {database.name} ({len(database):,} activities)")
# Out:
# Using biosphere database: biosphere-3.12 (version (3, 12))
# Adding ('IPCC 2021', 'climate change', 'GWP 100a, incl. H and bio CO2')
# Converting to ecoinvent 3.10+ biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.87 seconds
# Dropped 47 unlinked lower stratosphere + upper troposphere flows
# Wrote 1 LCIA methods with 208 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 100a, incl. H')
# Converting to ecoinvent 3.10+ biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.92 seconds
# Dropped 46 unlinked lower stratosphere + upper troposphere flows
# Wrote 1 LCIA methods with 202 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 20a, incl. H')
# Converting to ecoinvent 3.10+ biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 1.28 seconds
# Dropped 46 unlinked lower stratosphere + upper troposphere flows
# Wrote 1 LCIA methods with 202 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 20a, incl. H and bio CO2')
# Converting to ecoinvent 3.10+ biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 1.18 seconds
# Dropped 47 unlinked lower stratosphere + upper troposphere flows
# Wrote 1 LCIA methods with 208 characterization factors
# Project:  ecoinvent-3.12-cutoff
# Database: ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full (42,510 activities)

# %%
def exact_matches(name, location):
    return sorted(
        [
            activity for activity in database
            if activity.get("name") == name
            and activity.get("reference product") == REFERENCE_PRODUCT
            and activity.get("unit") == UNIT
            and activity.get("location") == location
        ],
        key=lambda activity: str(activity.key),
    )


def require_one(name, location):
    matches = exact_matches(name, location)
    if len(matches) != 1:
        raise LookupError(
            f"Expected exactly one match for {name!r} at {location!r}; found {len(matches)}."
        )
    return matches[0]


generic_rer = require_one(GENERIC_MARKET_NAME, TARGET_LOCATION)
selected = {"Generic": generic_rer}
sector_locations = {}
missing_sector_labels = []

for label, name in EXPECTED_SECTOR_MARKETS.items():
    chosen = None
    for location in (TARGET_LOCATION, *SECTOR_LOCATION_FALLBACKS):
        matches = exact_matches(name, location)
        if len(matches) > 1:
            raise LookupError(f"Multiple exact matches for {name!r} at {location!r}.")
        if matches:
            chosen = matches[0]
            break
    if chosen is None:
        missing_sector_labels.append(label)
    else:
        selected[label] = chosen
        sector_locations[label] = chosen.get("location")

if len(selected) == 1:
    raise LookupError("No European sector-specific hydrogen markets were found.")
if missing_sector_labels:
    warnings.warn(
        "No market was generated for these European sectors in this scenario: "
        + ", ".join(missing_sector_labels)
    )

fallback_locations_used = sorted(set(sector_locations.values()) - {TARGET_LOCATION})
if fallback_locations_used:
    warnings.warn(
        f"Sector markets are unavailable at {TARGET_LOCATION}; using mapped IAM location(s) "
        f"{fallback_locations_used}."
    )

selection_rows = [
    {
        "comparison label": label,
        "name": activity.get("name"),
        "reference product": activity.get("reference product"),
        "location": activity.get("location"),
        "unit": activity.get("unit"),
        "database key": activity.key,
    }
    for label, activity in selected.items()
]
selection_df = pd.DataFrame(selection_rows)
display(selection_df)
# Out:
# C:\Users\ac145674\AppData\Local\Temp\ipykernel_34300\2845316801.py:46: UserWarning: No market was generated for these European sectors in this scenario: Steel, Heating
#   warnings.warn(
# C:\Users\ac145674\AppData\Local\Temp\ipykernel_34300\2845316801.py:53: UserWarning: Sector markets are unavailable at RER; using mapped IAM location(s) ['EUR'].
#   warnings.warn(
#   comparison label  \
# 0          Generic
# 1        Transport
# 2        Chemicals
# 3           Cement
# 4   Other end uses
#
#                                                              name  \
# 0                      market for hydrogen, gaseous, low pressure
# 1       market for hydrogen, gaseous, low pressure, for transport
# 2       market for hydrogen, gaseous, low pressure, for chemicals
# 3          market for hydrogen, gaseous, low pressure, for cement
# 4  market for hydrogen, gaseous, low pressure, for other end uses
#
#                  reference product location      unit  \
# 0  hydrogen, gaseous, low pressure      RER  kilogram
# 1  hydrogen, gaseous, low pressure      EUR  kilogram
# 2  hydrogen, gaseous, low pressure      EUR  kilogram
# 3  hydrogen, gaseous, low pressure      EUR  kilogram
# 4  hydrogen, gaseous, low pressure      EUR  kilogram
#
#                                                                                database key
# 0  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 10035f79c9f540e7be87a75dbcae5084)
# 1  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 206fcb02587f45ba8f85b526ad383acc)
# 2  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 3ddb83705d96455fa7249d99835c81d1)
# 3  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, cfd6c9283b46483d897b2213b2717232)
# 4  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 7e808f459a0e4eb5abaa3495feff5e58)

# %% [markdown]
# ### Finalize the comparison order
#
# The requested generic `RER` market is followed by every sector-specific European market available in the configured database.

# %%
sector_order = [label for label in EXPECTED_SECTOR_MARKETS if label in selected]
market_order = ["Generic", *sector_order]

selection_df = pd.DataFrame([
    {
        "comparison label": label,
        "name": activity.get("name"),
        "reference product": activity.get("reference product"),
        "location": activity.get("location"),
        "unit": activity.get("unit"),
        "database key": activity.key,
    }
    for label, activity in selected.items()
])
display(selection_df)
# Out:
#   comparison label  \
# 0          Generic
# 1        Transport
# 2        Chemicals
# 3           Cement
# 4   Other end uses
#
#                                                              name  \
# 0                      market for hydrogen, gaseous, low pressure
# 1       market for hydrogen, gaseous, low pressure, for transport
# 2       market for hydrogen, gaseous, low pressure, for chemicals
# 3          market for hydrogen, gaseous, low pressure, for cement
# 4  market for hydrogen, gaseous, low pressure, for other end uses
#
#                  reference product location      unit  \
# 0  hydrogen, gaseous, low pressure      RER  kilogram
# 1  hydrogen, gaseous, low pressure      EUR  kilogram
# 2  hydrogen, gaseous, low pressure      EUR  kilogram
# 3  hydrogen, gaseous, low pressure      EUR  kilogram
# 4  hydrogen, gaseous, low pressure      EUR  kilogram
#
#                                                                                database key
# 0  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 10035f79c9f540e7be87a75dbcae5084)
# 1  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 206fcb02587f45ba8f85b526ad383acc)
# 2  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 3ddb83705d96455fa7249d99835c81d1)
# 3  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, cfd6c9283b46483d897b2213b2717232)
# 4  (ecoinvent-3.12-cutoff_remind-SSP2-NDC_2050_05-3_full, 7e808f459a0e4eb5abaa3495feff5e58)

# %% [markdown]
# ## 4. Select EF 3.1, premise hydrogen GWP, and CED methods
#
# All methods whose top-level family is exactly `EF v3.1` are included. `no LT` and `EN15804` variants are excluded to avoid mixing method families. The imported `IPCC 2021 — GWP 100a, incl. H` method is appended because it includes the characterization factor for hydrogen emissions to air. Two aggregate Cumulative Energy Demand methods are also appended: **non-renewable energy resources** and **renewable energy resources**, both expressed in MJ-Eq. Categories retain their individual physical units.

# %%
EXCLUDED_METHOD_TERMS = ("no LT", "EN15804")
ef31_methods = sorted([
    method for method in bd.methods
    if len(method) >= 2
    and method[0] == "EF v3.1"
    and not any(term.lower() in " | ".join(method).lower() for term in EXCLUDED_METHOD_TERMS)
])
if not ef31_methods:
    raise LookupError("No EF v3.1 methods were found in the current Brightway project.")

missing_ced_methods = [method for method in CED_METHODS if method not in bd.methods]
if missing_ced_methods:
    raise LookupError(f"Required CED methods are unavailable: {missing_ced_methods}")

lcia_methods = [*ef31_methods, PREMISE_GWP_METHOD, *CED_METHODS]
CONTRIBUTION_METHODS = [PREMISE_GWP_METHOD]

def impact_category_label(method):
    if method == PREMISE_GWP_METHOD:
        return "climate change — GWP 100a, incl. H (premise_gwp)"
    if method == CED_METHODS[0]:
        return "cumulative energy demand: non-renewable resources"
    if method == CED_METHODS[1]:
        return "cumulative energy demand: renewable sources"
    return method[1]

method_rows = []
for method in lcia_methods:
    metadata = bd.Method(method).metadata
    method_rows.append({
        "method": method,
        "impact category": impact_category_label(method),
        "indicator": method[-1],
        "unit": metadata.get("unit", ""),
    })
methods_df = pd.DataFrame(method_rows)
print(
    f"Selected {len(ef31_methods)} EF 3.1 impact categories, "
    f"{PREMISE_GWP_METHOD}, and {len(CED_METHODS)} aggregate CED methods."
)
display(methods_df)
# Out:
# Selected 25 EF 3.1 impact categories, ('IPCC 2021', 'climate change', 'GWP 100a, incl. H'), and 2 aggregate CED methods.
#                                                                                                              method  \
# 0                                                             (EF v3.1, acidification, accumulated exceedance (AE))
# 1                                                      (EF v3.1, climate change, global warming potential (GWP100))
# 2                                            (EF v3.1, climate change: biogenic, global warming potential (GWP100))
# 3                                              (EF v3.1, climate change: fossil, global warming potential (GWP100))
# 4                        (EF v3.1, climate change: land use and land use change, global warming potential (GWP100))
# 5                                  (EF v3.1, ecotoxicity: freshwater, comparative toxic unit for ecosystems (CTUe))
# 6                      (EF v3.1, ecotoxicity: freshwater, inorganics, comparative toxic unit for ecosystems (CTUe))
# 7                        (EF v3.1, ecotoxicity: freshwater, organics, comparative toxic unit for ecosystems (CTUe))
# 8                       (EF v3.1, energy resources: non-renewable, abiotic depletion potential (ADP): fossil fuels)
# 9              (EF v3.1, eutrophication: freshwater, fraction of nutrients reaching freshwater end compartment (P))
# 10                     (EF v3.1, eutrophication: marine, fraction of nutrients reaching marine end compartment (N))
# 11                                              (EF v3.1, eutrophication: terrestrial, accumulated exceedance (AE))
# 12                                 (EF v3.1, human toxicity: carcinogenic, comparative toxic unit for human (CTUh))
# 13                     (EF v3.1, human toxicity: carcinogenic, inorganics, comparative toxic unit for human (CTUh))
# 14                       (EF v3.1, human toxicity: carcinogenic, organics, comparative toxic unit for human (CTUh))
# 15                             (EF v3.1, human toxicity: non-carcinogenic, comparative toxic unit for human (CTUh))
# 16                 (EF v3.1, human toxicity: non-carcinogenic, inorganics, comparative toxic unit for human (CTUh))
# 17                   (EF v3.1, human toxicity: non-carcinogenic, organics, comparative toxic unit for human (CTUh))
# 18                          (EF v3.1, ionising radiation: human health, human exposure efficiency relative to u235)
# 19                                                                          (EF v3.1, land use, soil quality index)
# 20  (EF v3.1, material resources: metals/minerals, abiotic depletion potential (ADP): elements (ultimate reserves))
# 21                                                      (EF v3.1, ozone depletion, ozone depletion potential (ODP))
# 22                                                  (EF v3.1, particulate matter formation, impact on human health)
# 23              (EF v3.1, photochemical oxidant formation: human health, tropospheric ozone concentration increase)
# 24                        (EF v3.1, water use, user deprivation potential (deprivation-weighted water consumption))
# 25                                                                   (IPCC 2021, climate change, GWP 100a, incl. H)
# 26                          (Cumulative Energy Demand (CED), energy resources: non-renewable, energy content (HHV))
# 27                              (Cumulative Energy Demand (CED), energy resources: renewable, energy content (HHV))
#
#                                       impact category  \
# 0                                       acidification
# 1                                      climate change
# 2                            climate change: biogenic
# 3                              climate change: fossil
# 4        climate change: land use and land use change
# 5                             ecotoxicity: freshwater
# 6                 ecotoxicity: freshwater, inorganics
# 7                   ecotoxicity: freshwater, organics
# 8                     energy resources: non-renewable
# 9                          eutrophication: freshwater
# 10                             eutrophication: marine
# 11                        eutrophication: terrestrial
# 12                       human toxicity: carcinogenic
# 13           human toxicity: carcinogenic, inorganics
# 14             human toxicity: carcinogenic, organics
# 15                   human toxicity: non-carcinogenic
# 16       human toxicity: non-carcinogenic, inorganics
# 17         human toxicity: non-carcinogenic, organics
# 18                   ionising radiation: human health
# 19                                           land use
# 20                material resources: metals/minerals
# 21                                    ozone depletion
# 22                       particulate matter formation
# 23      photochemical oxidant formation: human health
# 24                                          water use
# 25   climate change — GWP 100a, incl. H (premise_gwp)
# 26  cumulative energy demand: non-renewable resources
# 27        cumulative energy demand: renewable sources
#
#                                                               indicator  \
# 0                                           accumulated exceedance (AE)
# 1                                     global warming potential (GWP100)
# 2                                     global warming potential (GWP100)
# 3                                     global warming potential (GWP100)
# 4                                     global warming potential (GWP100)
# 5                          comparative toxic unit for ecosystems (CTUe)
# 6                          comparative toxic unit for ecosystems (CTUe)
# 7                          comparative toxic unit for ecosystems (CTUe)
# 8                       abiotic depletion potential (ADP): fossil fuels
# 9         fraction of nutrients reaching freshwater end compartment (P)
# 10            fraction of nutrients reaching marine end compartment (N)
# 11                                          accumulated exceedance (AE)
# 12                              comparative toxic unit for human (CTUh)
# 13                              comparative toxic unit for human (CTUh)
# 14                              comparative toxic unit for human (CTUh)
# 15                              comparative toxic unit for human (CTUh)
# 16                              comparative toxic unit for human (CTUh)
# 17                              comparative toxic unit for human (CTUh)
# 18                           human exposure efficiency relative to u235
# 19                                                   soil quality index
# 20      abiotic depletion potential (ADP): elements (ultimate reserves)
# 21                                      ozone depletion potential (ODP)
# 22                                               impact on human health
# 23                            tropospheric ozone concentration increase
# 24  user deprivation potential (deprivation-weighted water consumption)
# 25                                                    GWP 100a, incl. H
# 26                                                 energy content (HHV)
# 27                                                 energy content (HHV)
#
#                        unit
# 0                 mol H+-Eq
# 1                 kg CO2-Eq
# 2                 kg CO2-Eq
# 3                 kg CO2-Eq
# 4                 kg CO2-Eq
# 5                      CTUe
# 6                      CTUe
# 7                      CTUe
# 8   MJ, net calorific value
# 9                   kg P-Eq
# 10                  kg N-Eq
# 11                 mol N-Eq
# 12                     CTUh
# 13                     CTUh
# 14                     CTUh
# 15                     CTUh
# 16                     CTUh
# 17                     CTUh
# 18              kBq U235-Eq
# 19            dimensionless
# 20                 kg Sb-Eq
# 21             kg CFC-11-Eq
# 22        disease incidence
# 23              kg NMVOC-Eq
# 24     m3 world Eq deprived
# 25                kg CO2-Eq
# 26                    MJ-Eq
# 27                    MJ-Eq

# %% [markdown]
# ## 5. Calculate LCIA scores and premise-GWP process contributions
#
# For each 1 kg market demand, Brightway solves the technosphere system once and switches among all selected EF 3.1, premise GWP, and CED methods to calculate the comparative LCIA scores. Process contributions are calculated only for the hydrogen-inclusive `PREMISE_GWP_METHOD`. Its characterized inventory is summed by technosphere column and processes are ranked by absolute score, retaining negative credits.

# %%
def reverse_activity_index(lca):
    if hasattr(lca, "dicts") and hasattr(lca.dicts, "activity"):
        reverse = lca.dicts.activity.reversed
        return dict(reverse) if not isinstance(reverse, dict) else reverse
    if hasattr(lca, "activity_dict"):
        return {index: key for key, index in lca.activity_dict.items()}
    raise AttributeError("Could not find the Brightway activity index on the LCA object.")


def get_activity_from_key(key):
    try:
        return bd.get_activity(key)
    except Exception:
        return bd.get_node(id=key)


def top_process_rows(lca, market_label, activity, method, unit, top_n):
    process_scores = np.asarray(lca.characterized_inventory.sum(axis=0)).ravel()
    reverse = reverse_activity_index(lca)
    nonzero = np.flatnonzero(process_scores)
    ordered = nonzero[np.argsort(np.abs(process_scores[nonzero]))[::-1]]
    kept = ordered[:top_n]
    rows = []
    for rank, column in enumerate(kept, start=1):
        process = get_activity_from_key(reverse[int(column)])
        score = float(process_scores[column])
        rows.append({
            "market": market_label,
            "market location": activity.get("location"),
            "impact category": impact_category_label(method),
            "indicator": method[-1],
            "method": method,
            "unit": unit,
            "rank": rank,
            "process": process.get("name", str(process)),
            "process location": process.get("location", ""),
            "process key": process.key,
            "score": score,
            "share (%)": 100.0 * score / lca.score if lca.score != 0 else np.nan,
        })
    other_score = float(process_scores.sum() - process_scores[kept].sum())
    rows.append({
        "market": market_label,
        "market location": activity.get("location"),
        "impact category": impact_category_label(method),
        "indicator": method[-1],
        "method": method,
        "unit": unit,
        "rank": top_n + 1,
        "process": "Other",
        "process location": "",
        "process key": None,
        "score": other_score,
        "share (%)": 100.0 * other_score / lca.score if lca.score != 0 else np.nan,
    })
    return rows

# %%
score_records = []
contribution_records = []
method_units = {row["method"]: row["unit"] for row in method_rows}

for market_label, activity in selected.items():
    lca = bc.LCA({activity: FUNCTIONAL_UNIT_KG}, lcia_methods[0])
    lca.lci()
    for method in lcia_methods:
        lca.switch_method(method)
        lca.lcia()
        unit = method_units[method]
        score_records.append({
            "market": market_label,
            "market name": activity.get("name"),
            "location": activity.get("location"),
            "impact category": impact_category_label(method),
            "indicator": method[-1],
            "method": method,
            "unit": unit,
            "score per kg H2": float(lca.score),
        })
        if method in CONTRIBUTION_METHODS:
            contribution_records.extend(
                top_process_rows(lca, market_label, activity, method, unit, TOP_N_PROCESSES)
            )
    print(f"Finished {market_label} [{activity.get('location')}]")

scores_df = pd.DataFrame(score_records)
contributions_df = pd.DataFrame(contribution_records)
categories = scores_df["impact category"].drop_duplicates().tolist()
display(scores_df.head())
# Out:
# Finished Generic [RER]
# Finished Transport [EUR]
# Finished Chemicals [EUR]
# Finished Cement [EUR]
# Finished Other end uses [EUR]
#     market                                 market name location  \
# 0  Generic  market for hydrogen, gaseous, low pressure      RER
# 1  Generic  market for hydrogen, gaseous, low pressure      RER
# 2  Generic  market for hydrogen, gaseous, low pressure      RER
# 3  Generic  market for hydrogen, gaseous, low pressure      RER
# 4  Generic  market for hydrogen, gaseous, low pressure      RER
#
#                                 impact category  \
# 0                                 acidification
# 1                                climate change
# 2                      climate change: biogenic
# 3                        climate change: fossil
# 4  climate change: land use and land use change
#
#                            indicator  \
# 0        accumulated exceedance (AE)
# 1  global warming potential (GWP100)
# 2  global warming potential (GWP100)
# 3  global warming potential (GWP100)
# 4  global warming potential (GWP100)
#
#                                                                                        method  \
# 0                                       (EF v3.1, acidification, accumulated exceedance (AE))
# 1                                (EF v3.1, climate change, global warming potential (GWP100))
# 2                      (EF v3.1, climate change: biogenic, global warming potential (GWP100))
# 3                        (EF v3.1, climate change: fossil, global warming potential (GWP100))
# 4  (EF v3.1, climate change: land use and land use change, global warming potential (GWP100))
#
#         unit  score per kg H2
# 0  mol H+-Eq         0.018911
# 1  kg CO2-Eq         1.034410
# 2  kg CO2-Eq         0.007493
# 3  kg CO2-Eq         1.007710
# 4  kg CO2-Eq         0.019207

# %% [markdown]
# ### Quality-control checks
#
# The top-process rows plus the exact `Other` remainder must reconstruct every total LCIA score. The calculation also verifies one result per selected market and EF method.

# %%
expected_result_count = len(selected) * len(lcia_methods)
if len(scores_df) != expected_result_count:
    raise AssertionError(f"Expected {expected_result_count} LCIA results; found {len(scores_df)}.")

reconstructed = (
    contributions_df.groupby(["market", "method"], as_index=False)["score"].sum()
    .rename(columns={"score": "reconstructed score"})
)
expected_contribution_results = len(selected) * len(CONTRIBUTION_METHODS)
if len(reconstructed) != expected_contribution_results:
    raise AssertionError(
        f"Expected {expected_contribution_results} contribution results; found {len(reconstructed)}."
    )
check_df = (
    scores_df[scores_df["method"].isin(CONTRIBUTION_METHODS)]
    .merge(reconstructed, on=["market", "method"], validate="one_to_one")
)
check_df["absolute difference"] = (
    check_df["score per kg H2"] - check_df["reconstructed score"]
).abs()
tolerance = 1e-9 * np.maximum(1.0, check_df["score per kg H2"].abs())
if not np.all(check_df["absolute difference"] <= tolerance):
    raise AssertionError("Process contributions do not reconstruct one or more LCIA totals.")
print(f"All {len(check_df)} contribution totals reconstruct their LCIA scores.")
# Out:
# All 5 contribution totals reconstruct their LCIA scores.

# %% [markdown]
# ## 6. Compare absolute LCIA impacts per kg H2
#
# Each subplot is one LCIA category with its own unit. The comparison includes all EF 3.1 categories, premise hydrogen-inclusive GWP100, and aggregate renewable and non-renewable CED. Bars are comparable within a subplot only.

# %%
ncols = 3
nrows = math.ceil(len(categories) / ncols)
fig, axes = plt.subplots(nrows, ncols, figsize=(22, 5.2 * nrows), squeeze=False)
colors = ["#4c78a8", *plt.get_cmap("Set2")(np.linspace(0, 1, max(len(sector_order), 1)))]
for ax, category in zip(axes.ravel(), categories):
    subset = (
        scores_df[scores_df["impact category"] == category]
        .set_index("market")
        .reindex(market_order)
    )
    values = subset["score per kg H2"].to_numpy(dtype=float)
    bars = ax.bar(np.arange(len(market_order)), values, color=colors[:len(market_order)])
    ax.axhline(0, color="black", linewidth=0.8)
    ax.set_title(category, fontsize=16, pad=12)
    ax.set_ylabel(f"{subset['unit'].iloc[0]} / kg H2", fontsize=14)
    ax.set_xticks(np.arange(len(market_order)), market_order, rotation=38, ha="right", fontsize=12)
    ax.tick_params(axis="y", labelsize=12)
    for bar, value in zip(bars, values):
        ax.annotate(
            f"{value:.2e}",
            (bar.get_x() + bar.get_width() / 2, value),
            xytext=(5, 10 if value >= 0 else -12),
            textcoords="offset points", ha="center", fontsize=10, rotation=90,
        )
    nonzero_abs = np.abs(values[np.isfinite(values) & (values != 0)])
    if len(nonzero_abs) and nonzero_abs.max() / nonzero_abs.min() > 1_000:
        ax.set_yscale("symlog", linthresh=max(nonzero_abs.min(), 1e-30))

for ax in axes.ravel()[len(categories):]:
    ax.set_visible(False)
fig.suptitle("Absolute LCIA impacts: EF 3.1, hydrogen GWP, and CED (functional unit: 1 kg H2)", fontsize=20, y=1.002)
fig.tight_layout()
#plt.show()

# %% [markdown]
# ## 7. Difference from the requested generic RER market
#
# Absolute and percentage differences use the single `Generic (RER)` market as the baseline. Percentage differences are undefined when the generic score is zero.

# %%
def comparison_to_baseline(baseline_label, comparison_labels):
    baseline = (
        scores_df[scores_df["market"] == baseline_label]
        [["method", "score per kg H2"]]
        .rename(columns={"score per kg H2": "baseline score per kg H2"})
    )
    compared = scores_df[scores_df["market"].isin(comparison_labels)].merge(
        baseline, on="method", validate="many_to_one"
    )
    compared["absolute difference"] = (
        compared["score per kg H2"] - compared["baseline score per kg H2"]
    )
    compared["difference (%)"] = np.where(
        compared["baseline score per kg H2"] != 0,
        100.0 * compared["absolute difference"] / compared["baseline score per kg H2"],
        np.nan,
    )
    compared["baseline"] = baseline_label
    return compared


comparison_rer_df = comparison_to_baseline("Generic", sector_order)
display(comparison_rer_df[[
    "market", "location", "impact category", "unit",
    "score per kg H2", "baseline score per kg H2",
    "absolute difference", "difference (%)",
]])
# Out:
#              market location  \
# 0         Transport      EUR
# 1         Transport      EUR
# 2         Transport      EUR
# 3         Transport      EUR
# 4         Transport      EUR
# ..              ...      ...
# 107  Other end uses      EUR
# 108  Other end uses      EUR
# 109  Other end uses      EUR
# 110  Other end uses      EUR
# 111  Other end uses      EUR
#
#                                        impact category                  unit  \
# 0                                        acidification             mol H+-Eq
# 1                                       climate change             kg CO2-Eq
# 2                             climate change: biogenic             kg CO2-Eq
# 3                               climate change: fossil             kg CO2-Eq
# 4         climate change: land use and land use change             kg CO2-Eq
# ..                                                 ...                   ...
# 107      photochemical oxidant formation: human health           kg NMVOC-Eq
# 108                                          water use  m3 world Eq deprived
# 109   climate change — GWP 100a, incl. H (premise_gwp)             kg CO2-Eq
# 110  cumulative energy demand: non-renewable resources                 MJ-Eq
# 111        cumulative energy demand: renewable sources                 MJ-Eq
#
#      score per kg H2  baseline score per kg H2  absolute difference  \
# 0           0.020234                  0.018911             0.001323
# 1           1.120627                  1.034410             0.086217
# 2           0.007927                  0.007493             0.000434
# 3           1.092192                  1.007710             0.084482
# 4           0.020508                  0.019207             0.001301
# ..               ...                       ...                  ...
# 107         0.008242                  0.007732             0.000510
# 108         2.328913                  2.170445             0.158468
# 109         1.250089                  1.128866             0.121223
# 110        42.324292                 40.221579             2.102713
# 111       207.094994                196.092251            11.002743
#
#      difference (%)
# 0          6.996660
# 1          8.334892
# 2          5.792525
# 3          8.383520
# 4          6.775341
# ..              ...
# 107        6.594698
# 108        7.301183
# 109       10.738505
# 110        5.227823
# 111        5.611003
#
# [112 rows x 8 columns]

# %%
difference_matrix = (
    comparison_rer_df.pivot(index="impact category", columns="market", values="difference (%)")
    .reindex(index=categories, columns=sector_order)
)
finite_values = difference_matrix.to_numpy(dtype=float)
finite_values = finite_values[np.isfinite(finite_values)]
color_limit = max(10.0, np.percentile(np.abs(finite_values), 95)) if len(finite_values) else 100.0

fig, ax = plt.subplots(figsize=(max(11, 2.0 * len(sector_order)), max(9, 0.58 * len(categories))))
image = ax.imshow(
    difference_matrix.to_numpy(), cmap="RdBu_r",
    vmin=-color_limit, vmax=color_limit, aspect="auto",
)
ax.set_xticks(np.arange(len(sector_order)), sector_order, rotation=35, ha="right", fontsize=12)
ax.set_yticks(np.arange(len(categories)), categories, fontsize=11)
for i in range(difference_matrix.shape[0]):
    for j in range(difference_matrix.shape[1]):
        value = difference_matrix.iat[i, j]
        if np.isfinite(value):
            ax.text(j, i, f"{value:+.0f}%", ha="center", va="center", fontsize=10,
                    color="white" if abs(value) > 0.55 * color_limit else "black")
colorbar = fig.colorbar(image, ax=ax)
colorbar.set_label("Difference from generic market, %", fontsize=13)
colorbar.ax.tick_params(labelsize=11)
ax.set_title("Sector-specific hydrogen markets relative to generic market", fontsize=17, pad=14)
fig.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Selected-impact hotspot analysis by process group
#
# The hotspot analysis retains ten decision-relevant impact categories. Each panel reports absolute contributions in its own method unit per kg H2 and uses the Layer 1 process groups defined below: individual hydrogen production technologies and aggregated hydrogen distribution. Only transport-related hydrogen and ammonia emissions are classified as leakage. Percentage labels are signed shares of the corresponding market total; positive and negative contributions are stacked separately so credits remain visible. Values and axes must not be compared numerically across impact categories with different units.

# %%
HOTSPOT_IMPACT_CATEGORY_ORDER = [
    "acidification",
    "climate change — GWP 100a, incl. H (premise_gwp)",
    "ecotoxicity: freshwater",
    "energy resources: non-renewable",
    "eutrophication: freshwater",
    "eutrophication: marine",
    "human toxicity: carcinogenic",
    "human toxicity: non-carcinogenic",
    "material resources: metals/minerals",
    "particulate matter formation",
]

# %% [markdown]
# The following cell performs the hotspot process-group calculation and reconciliation for the shared category list.

# %%
import importlib
import sys

stage_module_dir = Path.cwd() if Path.cwd().name == "dev" else Path.cwd() / "dev"
if str(stage_module_dir) not in sys.path:
    sys.path.insert(0, str(stage_module_dir))
import lcia_stage_analysis as stage_analysis
importlib.reload(stage_analysis)

hotspot_method_candidates = [*ef31_methods, PREMISE_GWP_METHOD]
hotspot_methods_by_category = {}
for category in HOTSPOT_IMPACT_CATEGORY_ORDER:
    matches = [
        method for method in hotspot_method_candidates
        if impact_category_label(method) == category
    ]
    if len(matches) != 1:
        raise LookupError(
            f"Expected exactly one LCIA method for hotspot category {category!r}; "
            f"found {len(matches)}: {matches}"
        )
    hotspot_methods_by_category[category] = matches[0]

hotspot_layer1_frames = []
hotspot_reconciliation_frames = []
for category, method in hotspot_methods_by_category.items():
    result = stage_analysis.analyze_hydrogen_life_cycle_stages(
        selected=selected,
        market_order=market_order,
        method=method,
        functional_unit=FUNCTIONAL_UNIT_KG,
        scores_df=scores_df,
        impact_category=category,
        unit=method_units[method],
        reconciliation_rtol=1e-5,
    )
    hotspot_layer1_frames.append(result["layer1"])
    hotspot_reconciliation_frames.append(result["reconciliation"])
    print(f"Finished hotspot process-group analysis: {category}")

hotspot_layer1_df = pd.concat(hotspot_layer1_frames, ignore_index=True)
hotspot_reconciliation_df = pd.concat(
    hotspot_reconciliation_frames, ignore_index=True
)
hotspot_process_group_df = (
    hotspot_layer1_df.groupby(
        [
            "market", "method", "impact category", "unit",
            "layer 1 group", "component",
        ],
        as_index=False,
        dropna=False,
    )["score"].sum()
    .rename(columns={"score": "absolute contribution"})
)
hotspot_totals_df = (
    scores_df[scores_df["method"].isin(hotspot_methods_by_category.values())]
    [["market", "method", "score per kg H2"]]
)
hotspot_process_group_df = hotspot_process_group_df.merge(
    hotspot_totals_df,
    on=["market", "method"],
    validate="many_to_one",
)
hotspot_process_group_df["share of total impact (%)"] = np.where(
    hotspot_process_group_df["score per kg H2"] != 0,
    100.0
    * hotspot_process_group_df["absolute contribution"]
    / hotspot_process_group_df["score per kg H2"],
    np.nan,
)
hotspot_process_group_df["impact category"] = pd.Categorical(
    hotspot_process_group_df["impact category"],
    categories=HOTSPOT_IMPACT_CATEGORY_ORDER,
    ordered=True,
)
hotspot_process_group_df = hotspot_process_group_df.sort_values(
    ["impact category", "market", "layer 1 group", "component"]
).reset_index(drop=True)

display(hotspot_process_group_df)
display(hotspot_reconciliation_df)

process_group_order = hotspot_process_group_df["component"].drop_duplicates().tolist()
process_group_colors = stage_analysis.stage_layer1_color_map(
    hotspot_layer1_df
)

ncols = 2
nrows = math.ceil(len(HOTSPOT_IMPACT_CATEGORY_ORDER) / ncols)
fig, axes = plt.subplots(
    nrows,
    ncols,
    figsize=(22, 5.8 * nrows),
    squeeze=False,
)
for ax, category in zip(axes.ravel(), HOTSPOT_IMPACT_CATEGORY_ORDER):
    subset = hotspot_process_group_df[
        hotspot_process_group_df["impact category"] == category
    ]
    x = np.arange(len(market_order))
    positive_bottom = np.zeros(len(market_order))
    negative_bottom = np.zeros(len(market_order))
    totals = (
        subset.groupby("market")["score per kg H2"]
        .first()
        .reindex(market_order)
        .to_numpy(dtype=float)
    )

    for component in process_group_order:
        values = (
            subset[subset["component"] == component]
            .groupby("market")["absolute contribution"]
            .sum()
            .reindex(market_order, fill_value=0.0)
            .to_numpy(dtype=float)
        )
        if not np.any(values):
            continue
        bottom = np.where(values >= 0, positive_bottom, negative_bottom)
        bars = ax.bar(
            x,
            values,
            bottom=bottom,
            color=process_group_colors[component],
            edgecolor="white",
            linewidth=0.6,
            label=component,
        )
        shares = np.divide(
            100.0 * values,
            totals,
            out=np.full_like(values, np.nan),
            where=totals != 0,
        )
        for bar, value, share, start in zip(bars, values, shares, bottom):
            if np.isfinite(share) and abs(share) >= 5.0:
                ax.text(
                    bar.get_x() + bar.get_width() / 2,
                    start + value / 2,
                    f"{share:.0f}%",
                    ha="center",
                    va="center",
                    fontsize=8,
                )
        positive_bottom += np.where(values >= 0, values, 0.0)
        negative_bottom += np.where(values < 0, values, 0.0)

    unit = subset["unit"].iloc[0]
    ax.axhline(0, color="black", linewidth=0.8)
    ax.set_title(category, fontsize=15, pad=10)
    ax.set_ylabel(f"Absolute contribution ({unit} / kg H2)")
    ax.set_xticks(x, market_order, rotation=38, ha="right")

for ax in axes.ravel()[len(HOTSPOT_IMPACT_CATEGORY_ORDER):]:
    ax.set_visible(False)

legend_handles = {}
for ax in axes.ravel():
    for handle, label in zip(*ax.get_legend_handles_labels()):
        legend_handles.setdefault(label, handle)
fig.legend(
    legend_handles.values(),
    legend_handles.keys(),
    title="Layer 1 process group",
    bbox_to_anchor=(0.995, 0.5),
    loc="center left",
    frameon=False,
)
fig.suptitle(
    "Selected-impact hotspots by process group (functional unit: 1 kg H2)",
    fontsize=20,
    y=0.995,
)
fig.tight_layout(rect=(0, 0, 0.83, 0.98))
plt.show()
# Out:
# Finished hotspot process-group analysis: acidification
# Finished hotspot process-group analysis: climate change — GWP 100a, incl. H (premise_gwp)
# Finished hotspot process-group analysis: ecotoxicity: freshwater
# Finished hotspot process-group analysis: energy resources: non-renewable
# Finished hotspot process-group analysis: eutrophication: freshwater
# Finished hotspot process-group analysis: eutrophication: marine
# Finished hotspot process-group analysis: human toxicity: carcinogenic
# Finished hotspot process-group analysis: human toxicity: non-carcinogenic
# Finished hotspot process-group analysis: material resources: metals/minerals
# Finished hotspot process-group analysis: particulate matter formation
#         market  \
# 0       Cement
# 1       Cement
# 2       Cement
# 3       Cement
# 4       Cement
# ..         ...
# 345  Transport
# 346  Transport
# 347  Transport
# 348  Transport
# 349  Transport
#
#                                                               method  \
# 0              (EF v3.1, acidification, accumulated exceedance (AE))
# 1              (EF v3.1, acidification, accumulated exceedance (AE))
# 2              (EF v3.1, acidification, accumulated exceedance (AE))
# 3              (EF v3.1, acidification, accumulated exceedance (AE))
# 4              (EF v3.1, acidification, accumulated exceedance (AE))
# ..                                                               ...
# 345  (EF v3.1, particulate matter formation, impact on human health)
# 346  (EF v3.1, particulate matter formation, impact on human health)
# 347  (EF v3.1, particulate matter formation, impact on human health)
# 348  (EF v3.1, particulate matter formation, impact on human health)
# 349  (EF v3.1, particulate matter formation, impact on human health)
#
#                   impact category               unit          layer 1 group  \
# 0                   acidification          mol H+-Eq  Hydrogen distribution
# 1                   acidification          mol H+-Eq  Hydrogen distribution
# 2                   acidification          mol H+-Eq  Production technology
# 3                   acidification          mol H+-Eq  Production technology
# 4                   acidification          mol H+-Eq  Production technology
# ..                            ...                ...                    ...
# 345  particulate matter formation  disease incidence  Production technology
# 346  particulate matter formation  disease incidence  Production technology
# 347  particulate matter formation  disease incidence  Production technology
# 348  particulate matter formation  disease incidence  Production technology
# 349  particulate matter formation  disease incidence  Production technology
#
#                             component  absolute contribution  score per kg H2  \
# 0               Hydrogen distribution           2.105418e-03     1.999668e-02
# 1     Hydrogen leakage — distribution           0.000000e+00     1.999668e-02
# 2                Biomass gasification           4.770685e-04     1.999668e-02
# 3       Biomass gasification with CCS           1.022942e-08     1.999668e-02
# 4          Coal gasification with CCS           8.984339e-08     1.999668e-02
# ..                                ...                    ...              ...
# 345              Biomass gasification           1.168612e-08     1.180268e-07
# 346     Biomass gasification with CCS           2.039183e-13     1.180268e-07
# 347        Coal gasification with CCS           6.738932e-13     1.180268e-07
# 348                  PEM electrolysis           8.802128e-08     1.180268e-07
# 349  Steam methane reforming with CCS           4.370862e-09     1.180268e-07
#
#      share of total impact (%)
# 0                    10.528836
# 1                     0.000000
# 2                     2.385739
# 3                     0.000051
# 4                     0.000449
# ..                         ...
# 345                   9.901236
# 346                   0.000173
# 347                   0.000571
# 348                  74.577337
# 349                   3.703278
#
# [350 rows x 9 columns]
#             market  \
# 0          Generic
# 1        Transport
# 2        Chemicals
# 3           Cement
# 4   Other end uses
# 5          Generic
# 6        Transport
# 7        Chemicals
# 8           Cement
# 9   Other end uses
# 10         Generic
# 11       Transport
# 12       Chemicals
# 13          Cement
# 14  Other end uses
# 15         Generic
# 16       Transport
# 17       Chemicals
# 18          Cement
# 19  Other end uses
# 20         Generic
# 21       Transport
# 22       Chemicals
# 23          Cement
# 24  Other end uses
# 25         Generic
# 26       Transport
# 27       Chemicals
# 28          Cement
# 29  Other end uses
# 30         Generic
# 31       Transport
# 32       Chemicals
# 33          Cement
# 34  Other end uses
# 35         Generic
# 36       Transport
# 37       Chemicals
# 38          Cement
# 39  Other end uses
# 40         Generic
# 41       Transport
# 42       Chemicals
# 43          Cement
# 44  Other end uses
# 45         Generic
# 46       Transport
# 47       Chemicals
# 48          Cement
# 49  Other end uses
#
#                                                                                                              method  \
# 0                                                             (EF v3.1, acidification, accumulated exceedance (AE))
# 1                                                             (EF v3.1, acidification, accumulated exceedance (AE))
# 2                                                             (EF v3.1, acidification, accumulated exceedance (AE))
# 3                                                             (EF v3.1, acidification, accumulated exceedance (AE))
# 4                                                             (EF v3.1, acidification, accumulated exceedance (AE))
# 5                                                                    (IPCC 2021, climate change, GWP 100a, incl. H)
# 6                                                                    (IPCC 2021, climate change, GWP 100a, incl. H)
# 7                                                                    (IPCC 2021, climate change, GWP 100a, incl. H)
# 8                                                                    (IPCC 2021, climate change, GWP 100a, incl. H)
# 9                                                                    (IPCC 2021, climate change, GWP 100a, incl. H)
# 10                                 (EF v3.1, ecotoxicity: freshwater, comparative toxic unit for ecosystems (CTUe))
# 11                                 (EF v3.1, ecotoxicity: freshwater, comparative toxic unit for ecosystems (CTUe))
# 12                                 (EF v3.1, ecotoxicity: freshwater, comparative toxic unit for ecosystems (CTUe))
# 13                                 (EF v3.1, ecotoxicity: freshwater, comparative toxic unit for ecosystems (CTUe))
# 14                                 (EF v3.1, ecotoxicity: freshwater, comparative toxic unit for ecosystems (CTUe))
# 15                      (EF v3.1, energy resources: non-renewable, abiotic depletion potential (ADP): fossil fuels)
# 16                      (EF v3.1, energy resources: non-renewable, abiotic depletion potential (ADP): fossil fuels)
# 17                      (EF v3.1, energy resources: non-renewable, abiotic depletion potential (ADP): fossil fuels)
# 18                      (EF v3.1, energy resources: non-renewable, abiotic depletion potential (ADP): fossil fuels)
# 19                      (EF v3.1, energy resources: non-renewable, abiotic depletion potential (ADP): fossil fuels)
# 20             (EF v3.1, eutrophication: freshwater, fraction of nutrients reaching freshwater end compartment (P))
# 21             (EF v3.1, eutrophication: freshwater, fraction of nutrients reaching freshwater end compartment (P))
# 22             (EF v3.1, eutrophication: freshwater, fraction of nutrients reaching freshwater end compartment (P))
# 23             (EF v3.1, eutrophication: freshwater, fraction of nutrients reaching freshwater end compartment (P))
# 24             (EF v3.1, eutrophication: freshwater, fraction of nutrients reaching freshwater end compartment (P))
# 25                     (EF v3.1, eutrophication: marine, fraction of nutrients reaching marine end compartment (N))
# 26                     (EF v3.1, eutrophication: marine, fraction of nutrients reaching marine end compartment (N))
# 27                     (EF v3.1, eutrophication: marine, fraction of nutrients reaching marine end compartment (N))
# 28                     (EF v3.1, eutrophication: marine, fraction of nutrients reaching marine end compartment (N))
# 29                     (EF v3.1, eutrophication: marine, fraction of nutrients reaching marine end compartment (N))
# 30                                 (EF v3.1, human toxicity: carcinogenic, comparative toxic unit for human (CTUh))
# 31                                 (EF v3.1, human toxicity: carcinogenic, comparative toxic unit for human (CTUh))
# 32                                 (EF v3.1, human toxicity: carcinogenic, comparative toxic unit for human (CTUh))
# 33                                 (EF v3.1, human toxicity: carcinogenic, comparative toxic unit for human (CTUh))
# 34                                 (EF v3.1, human toxicity: carcinogenic, comparative toxic unit for human (CTUh))
# 35                             (EF v3.1, human toxicity: non-carcinogenic, comparative toxic unit for human (CTUh))
# 36                             (EF v3.1, human toxicity: non-carcinogenic, comparative toxic unit for human (CTUh))
# 37                             (EF v3.1, human toxicity: non-carcinogenic, comparative toxic unit for human (CTUh))
# 38                             (EF v3.1, human toxicity: non-carcinogenic, comparative toxic unit for human (CTUh))
# 39                             (EF v3.1, human toxicity: non-carcinogenic, comparative toxic unit for human (CTUh))
# 40  (EF v3.1, material resources: metals/minerals, abiotic depletion potential (ADP): elements (ultimate reserves))
# 41  (EF v3.1, material resources: metals/minerals, abiotic depletion potential (ADP): elements (ultimate reserves))
# 42  (EF v3.1, material resources: metals/minerals, abiotic depletion potential (ADP): elements (ultimate reserves))
# 43  (EF v3.1, material resources: metals/minerals, abiotic depletion potential (ADP): elements (ultimate reserves))
# 44  (EF v3.1, material resources: metals/minerals, abiotic depletion potential (ADP): elements (ultimate reserves))
# 45                                                  (EF v3.1, particulate matter formation, impact on human health)
# 46                                                  (EF v3.1, particulate matter formation, impact on human health)
# 47                                                  (EF v3.1, particulate matter formation, impact on human health)
# 48                                                  (EF v3.1, particulate matter formation, impact on human health)
# 49                                                  (EF v3.1, particulate matter formation, impact on human health)
#
#                                      impact category                     unit  \
# 0                                      acidification                mol H+-Eq
# 1                                      acidification                mol H+-Eq
# 2                                      acidification                mol H+-Eq
# 3                                      acidification                mol H+-Eq
# 4                                      acidification                mol H+-Eq
# 5   climate change — GWP 100a, incl. H (premise_gwp)                kg CO2-Eq
# 6   climate change — GWP 100a, incl. H (premise_gwp)                kg CO2-Eq
# 7   climate change — GWP 100a, incl. H (premise_gwp)                kg CO2-Eq
# 8   climate change — GWP 100a, incl. H (premise_gwp)                kg CO2-Eq
# 9   climate change — GWP 100a, incl. H (premise_gwp)                kg CO2-Eq
# 10                           ecotoxicity: freshwater                     CTUe
# 11                           ecotoxicity: freshwater                     CTUe
# 12                           ecotoxicity: freshwater                     CTUe
# 13                           ecotoxicity: freshwater                     CTUe
# 14                           ecotoxicity: freshwater                     CTUe
# 15                   energy resources: non-renewable  MJ, net calorific value
# 16                   energy resources: non-renewable  MJ, net calorific value
# 17                   energy resources: non-renewable  MJ, net calorific value
# 18                   energy resources: non-renewable  MJ, net calorific value
# 19                   energy resources: non-renewable  MJ, net calorific value
# 20                        eutrophication: freshwater                  kg P-Eq
# 21                        eutrophication: freshwater                  kg P-Eq
# 22                        eutrophication: freshwater                  kg P-Eq
# 23                        eutrophication: freshwater                  kg P-Eq
# 24                        eutrophication: freshwater                  kg P-Eq
# 25                            eutrophication: marine                  kg N-Eq
# 26                            eutrophication: marine                  kg N-Eq
# 27                            eutrophication: marine                  kg N-Eq
# 28                            eutrophication: marine                  kg N-Eq
# 29                            eutrophication: marine                  kg N-Eq
# 30                      human toxicity: carcinogenic                     CTUh
# 31                      human toxicity: carcinogenic                     CTUh
# 32                      human toxicity: carcinogenic                     CTUh
# 33                      human toxicity: carcinogenic                     CTUh
# 34                      human toxicity: carcinogenic                     CTUh
# 35                  human toxicity: non-carcinogenic                     CTUh
# 36                  human toxicity: non-carcinogenic                     CTUh
# 37                  human toxicity: non-carcinogenic                     CTUh
# 38                  human toxicity: non-carcinogenic                     CTUh
# 39                  human toxicity: non-carcinogenic                     CTUh
# 40               material resources: metals/minerals                 kg Sb-Eq
# 41               material resources: metals/minerals                 kg Sb-Eq
# 42               material resources: metals/minerals                 kg Sb-Eq
# 43               material resources: metals/minerals                 kg Sb-Eq
# 44               material resources: metals/minerals                 kg Sb-Eq
# 45                      particulate matter formation        disease incidence
# 46                      particulate matter formation        disease incidence
# 47                      particulate matter formation        disease incidence
# 48                      particulate matter formation        disease incidence
# 49                      particulate matter formation        disease incidence
#
#      total score  Layer 1 reconstructed score  Layer 1 difference  \
# 0   1.891086e-02                 1.891086e-02        9.720286e-11
# 1   2.023399e-02                 2.023399e-02        9.402583e-11
# 2   1.870694e-02                 1.870694e-02        8.504837e-11
# 3   1.999668e-02                 1.999668e-02        7.012002e-11
# 4   2.023399e-02                 2.023399e-02        9.402583e-11
# 5   1.128866e+00                 1.128866e+00        2.953634e-09
# 6   1.250089e+00                 1.250089e+00        2.522202e-09
# 7   1.100230e+00                 1.100230e+00        1.246822e-09
# 8   1.233742e+00                 1.233742e+00       -1.323119e-10
# 9   1.250089e+00                 1.250089e+00        2.522202e-09
# 10  2.527688e+01                 2.527688e+01        1.345277e-07
# 11  2.713371e+01                 2.713371e+01        1.292589e-07
# 12  2.499330e+01                 2.499330e+01        1.176251e-07
# 13  2.678575e+01                 2.678575e+01        9.801725e-08
# 14  2.713371e+01                 2.713371e+01        1.292589e-07
# 15  3.748956e+01                 3.748956e+01       -2.520502e-07
# 16  3.947970e+01                 3.947970e+01       -2.575211e-07
# 17  3.716030e+01                 3.716030e+01       -2.716751e-07
# 18  3.912211e+01                 3.912211e+01       -2.935119e-07
# 19  3.947970e+01                 3.947970e+01       -2.575211e-07
# 20  9.467143e-04                 9.467143e-04        5.455612e-12
# 21  1.016869e-03                 1.016869e-03        5.391891e-12
# 22  9.348718e-04                 9.348718e-04        4.749747e-12
# 23  1.006474e-03                 1.006474e-03        3.770526e-12
# 24  1.016869e-03                 1.016869e-03        5.391891e-12
# 25  2.265135e-03                 2.265135e-03        7.817059e-12
# 26  2.451130e-03                 2.451130e-03        6.682751e-12
# 27  2.242656e-03                 2.242656e-03        6.477272e-12
# 28  2.403516e-03                 2.403516e-03        5.600076e-12
# 29  2.451130e-03                 2.451130e-03        6.682751e-12
# 30  2.479645e-09                 2.479645e-09        1.241472e-17
# 31  2.657825e-09                 2.657825e-09        1.221014e-17
# 32  2.448119e-09                 2.448119e-09        1.053564e-17
# 33  2.631927e-09                 2.631927e-09        8.081326e-18
# 34  2.657825e-09                 2.657825e-09        1.221014e-17
# 35  1.468906e-07                 1.468906e-07        8.495081e-16
# 36  1.582445e-07                 1.582445e-07        8.391814e-16
# 37  1.450029e-07                 1.450029e-07        7.369919e-16
# 38  1.565435e-07                 1.565435e-07        5.791851e-16
# 39  1.582445e-07                 1.582445e-07        8.391814e-16
# 40  1.086592e-04                 1.086592e-04        6.596936e-13
# 41  1.166665e-04                 1.166665e-04        6.531672e-13
# 42  1.072530e-04                 1.072530e-04        5.758817e-13
# 43  1.155082e-04                 1.155082e-04        4.620323e-13
# 44  1.166665e-04                 1.166665e-04        6.531672e-13
# 45  1.104527e-07                 1.104527e-07        4.049524e-16
# 46  1.180268e-07                 1.180269e-07        3.770862e-16
# 47  1.091780e-07                 1.091780e-07        3.289753e-16
# 48  1.166248e-07                 1.166248e-07        2.555768e-16
# 49  1.180268e-07                 1.180269e-07        3.770862e-16
#
#     Layer 2 reconstructed score  Layer 2 difference
# 0                  1.891086e-02        2.219064e-10
# 1                  2.023399e-02        2.187294e-10
# 2                  1.870694e-02        2.097519e-10
# 3                  1.999668e-02        1.948235e-10
# 4                  2.023399e-02        2.187294e-10
# 5                  1.128866e+00        8.493558e-09
# 6                  1.250089e+00        8.062127e-09
# 7                  1.100230e+00        6.786746e-09
# 8                  1.233742e+00        5.407613e-09
# 9                  1.250089e+00        8.062127e-09
# 10                 2.527688e+01        3.112393e-07
# 11                 2.713371e+01        3.059705e-07
# 12                 2.499330e+01        2.943367e-07
# 13                 2.678575e+01        2.747288e-07
# 14                 2.713371e+01        3.059705e-07
# 15                 3.748956e+01       -4.994099e-07
# 16                 3.947970e+01       -5.048808e-07
# 17                 3.716030e+01       -5.190348e-07
# 18                 3.912211e+01       -5.408715e-07
# 19                 3.947970e+01       -5.048808e-07
# 20                 9.467143e-04        1.338460e-11
# 21                 1.016869e-03        1.332088e-11
# 22                 9.348718e-04        1.267874e-11
# 23                 1.006474e-03        1.169952e-11
# 24                 1.016869e-03        1.332088e-11
# 25                 2.265135e-03        1.987538e-11
# 26                 2.451130e-03        1.874108e-11
# 27                 2.242656e-03        1.853560e-11
# 28                 2.403516e-03        1.765840e-11
# 29                 2.451130e-03        1.874108e-11
# 30                 2.479645e-09        3.299534e-17
# 31                 2.657825e-09        3.279076e-17
# 32                 2.448119e-09        3.111627e-17
# 33                 2.631927e-09        2.866195e-17
# 34                 2.657825e-09        3.279076e-17
# 35                 1.468906e-07        2.154121e-15
# 36                 1.582445e-07        2.143794e-15
# 37                 1.450029e-07        2.041604e-15
# 38                 1.565435e-07        1.883798e-15
# 39                 1.582445e-07        2.143794e-15
# 40                 1.086592e-04        1.648624e-12
# 41                 1.166665e-04        1.642097e-12
# 42                 1.072530e-04        1.564812e-12
# 43                 1.155082e-04        1.450962e-12
# 44                 1.166665e-04        1.642097e-12
# 45                 1.104527e-07        1.064304e-15
# 46                 1.180269e-07        1.036437e-15
# 47                 1.091780e-07        9.883265e-16
# 48                 1.166248e-07        9.149279e-16
# 49                 1.180269e-07        1.036437e-15

# %% [markdown]
# ## 9. Selected-impact spider diagram relative to Generic (RER)
#
# This spider diagram uses exactly the impact categories defined by `HOTSPOT_IMPACT_CATEGORY_ORDER`. For each category, every market score is divided by the score of `Generic (RER)`. The generic market is therefore exactly **1** on every axis; a sector value of 2 means twice the generic impact, while 0.5 means half the generic impact. This is a ratio comparison, not EF normalization or weighting.

# %%
selected_impact_scores = scores_df[
    scores_df["impact category"].isin(HOTSPOT_IMPACT_CATEGORY_ORDER)
].copy()
selected_impact_score_matrix = (
    selected_impact_scores.pivot(
        index="impact category", columns="market", values="score per kg H2"
    )
    .reindex(index=HOTSPOT_IMPACT_CATEGORY_ORDER, columns=market_order)
)

generic_scores = selected_impact_score_matrix["Generic"]
zero_baselines = generic_scores.index[generic_scores == 0].tolist()
if zero_baselines:
    raise ZeroDivisionError(
        "Generic has a zero selected-impact score, so a relative ratio cannot be calculated for: "
        + ", ".join(zero_baselines)
    )

spider_ratio_df = selected_impact_score_matrix.div(generic_scores, axis=0)
spider_ratio_df["Generic"] = 1.0  # exact reference circle
if not np.isfinite(spider_ratio_df.to_numpy(dtype=float)).all():
    raise AssertionError("The selected-impact spider ratios contain non-finite values.")
if (spider_ratio_df.to_numpy(dtype=float) < 0).any():
    warnings.warn("Negative selected-impact ratios are present and require care on a polar chart.")

display(spider_ratio_df.rename_axis(columns="market"))

angles = np.linspace(0, 2 * np.pi, len(HOTSPOT_IMPACT_CATEGORY_ORDER), endpoint=False)
axis_labels = [category.replace(": ", ":\n") for category in HOTSPOT_IMPACT_CATEGORY_ORDER]

# Draw the spider in Cartesian coordinates. This is equivalent to a polar radar plot,
# while remaining compatible with Matplotlib installations whose polar projection is unavailable.
x_directions = np.sin(angles)  # start at the top and proceed clockwise
y_directions = np.cos(angles)
radial_max = max(1.1, float(spider_ratio_df[sector_order].max().max()) * 1.08)

fig, ax = plt.subplots(figsize=(16, 16))
grid_levels = sorted(set(np.linspace(0, radial_max, 5).tolist() + [1.0]))
circle_angles = np.linspace(0, 2 * np.pi, 361)
for level in grid_levels:
    if level == 0:
        continue
    ax.plot(
        level * np.sin(circle_angles), level * np.cos(circle_angles),
        color="black" if np.isclose(level, 1.0) else "#bdbdbd",
        linewidth=2.2 if np.isclose(level, 1.0) else 0.7,
        linestyle="--" if np.isclose(level, 1.0) else ":",
        label="Generic (RER) = 1" if np.isclose(level, 1.0) else None,
        zorder=5 if np.isclose(level, 1.0) else 1,
    )
    ax.text(0, level, f"{level:.2g}", fontsize=11, color="#555555", ha="left", va="bottom")

label_radius = radial_max * 1.12
for x_direction, y_direction, label in zip(x_directions, y_directions, axis_labels):
    ax.plot([0, radial_max * x_direction], [0, radial_max * y_direction],
            color="#d0d0d0", linewidth=0.6, zorder=0)
    horizontal_alignment = "center" if abs(x_direction) < 0.15 else ("left" if x_direction > 0 else "right")
    vertical_alignment = "center" if abs(y_direction) < 0.15 else ("bottom" if y_direction > 0 else "top")
    ax.text(
        label_radius * x_direction, label_radius * y_direction, label,
        fontsize=11, ha=horizontal_alignment, va=vertical_alignment,
    )

sector_colors = plt.get_cmap("tab10")(np.arange(len(sector_order)))
for color, market_label in zip(sector_colors, sector_order):
    values = spider_ratio_df[market_label].to_numpy(dtype=float)
    x_values = values * x_directions
    y_values = values * y_directions
    closed_x = np.r_[x_values, x_values[0]]
    closed_y = np.r_[y_values, y_values[0]]
    ax.plot(closed_x, closed_y, linewidth=1.8, color=color, label=market_label, zorder=3)
    ax.fill(closed_x, closed_y, color=color, alpha=0.06, zorder=2)

plot_limit = radial_max * 1.28
ax.set_xlim(-plot_limit, plot_limit)
ax.set_ylim(-plot_limit, plot_limit)
ax.set_aspect("equal", adjustable="box")
ax.axis("off")
ax.set_title(
    "Selected impacts relative to\ngeneric market = 1 in every category",
    fontsize=19, pad=38,
)
ax.legend(loc="upper left", bbox_to_anchor=(1.0, 1.02), frameon=False, fontsize=12)
fig.subplots_adjust(left=0.08, right=0.82, top=0.90, bottom=0.08)
plt.show()
# Out:
# market                                            Generic  Transport  \
# impact category
# acidification                                         1.0   1.069967
# climate change — GWP 100a, incl. H (premise_gwp)      1.0   1.107385
# ecotoxicity: freshwater                               1.0   1.073459
# energy resources: non-renewable                       1.0   1.053085
# eutrophication: freshwater                            1.0   1.074104
# eutrophication: marine                                1.0   1.082112
# human toxicity: carcinogenic                          1.0   1.071857
# human toxicity: non-carcinogenic                      1.0   1.077295
# material resources: metals/minerals                   1.0   1.073691
# particulate matter formation                          1.0   1.068574
#
# market                                            Chemicals    Cement  \
# impact category
# acidification                                      0.989217  1.057418
# climate change — GWP 100a, incl. H (premise_gwp)   0.974633  1.092904
# ecotoxicity: freshwater                            0.988781  1.059694
# energy resources: non-renewable                    0.991217  1.043547
# eutrophication: freshwater                         0.987491  1.063124
# eutrophication: marine                             0.990076  1.061092
# human toxicity: carcinogenic                       0.987286  1.061413
# human toxicity: non-carcinogenic                   0.987149  1.065715
# material resources: metals/minerals                0.987059  1.063031
# particulate matter formation                       0.988459  1.055880
#
# market                                            Other end uses
# impact category
# acidification                                           1.069967
# climate change — GWP 100a, incl. H (premise_gwp)        1.107385
# ecotoxicity: freshwater                                 1.073459
# energy resources: non-renewable                         1.053085
# eutrophication: freshwater                              1.074104
# eutrophication: marine                                  1.082112
# human toxicity: carcinogenic                            1.071857
# human toxicity: non-carcinogenic                        1.077295
# material resources: metals/minerals                     1.073691
# particulate matter formation                            1.068574

# %% [markdown]
# ## 10. Life-cycle-stage contribution analysis
#
# The hierarchical contribution analysis is calculated only for the hydrogen-inclusive `PREMISE_GWP_METHOD`; all other methods remain available in the comparative LCIA results. This analysis uses functional stages instead of graph distance.
#
# The **Process group CA - hydrogen production technologies and aggregated distribution** chart shows each hydrogen production technology in the market and aggregated hydrogen distribution as relative shares of the market total. **Layer 2** reports absolute premise-GWP contributions in the method unit per kg H2: it decomposes every production technology into its main direct-input groups. The **Process group CA - transport, conversion, and reconversion by market** chart combines all distribution processes in one plot. Direct hydrogen and ammonia emissions from distribution are reported as `Hydrogen leakage` and `Ammonia leakage`; production emissions remain assigned to their production technology. All branches retain their complete upstream LCIA burdens, and both layers are checked against the total market score.

# %%
import importlib
import sys

stage_module_dir = Path.cwd() if Path.cwd().name == "dev" else Path.cwd() / "dev"
if str(stage_module_dir) not in sys.path:
    sys.path.insert(0, str(stage_module_dir))
import lcia_stage_analysis as stage_analysis
importlib.reload(stage_analysis)

stage_results = stage_analysis.analyze_hydrogen_life_cycle_stages(
    selected=selected,
    market_order=market_order,
    method=PREMISE_GWP_METHOD,
    functional_unit=FUNCTIONAL_UNIT_KG,
    scores_df=scores_df,
    impact_category=impact_category_label(PREMISE_GWP_METHOD),
    unit=method_units[PREMISE_GWP_METHOD],
)

stage_layer1_df = stage_results["layer1"]
production_inputs_detailed_df = stage_results["production inputs detailed"]
production_input_groups_df = stage_results["production input groups"]
distribution_processes_df = stage_results["distribution processes"]
stage_classification_audit_df = stage_results["classification audit"]
stage_reconciliation_df = stage_results["reconciliation"]

display(stage_classification_audit_df)
display(stage_reconciliation_df)
display(stage_layer1_df.head(20))
display(production_input_groups_df.head(20))
display(distribution_processes_df.head(20))
# Out:
#             market market location  \
# 0          Generic             RER
# 1          Generic             RER
# 2          Generic             RER
# 3          Generic             RER
# 4          Generic             RER
# 5          Generic             RER
# 6          Generic             RER
# 7          Generic             RER
# 8        Transport             EUR
# 9        Transport             EUR
# 10       Transport             EUR
# 11       Transport             EUR
# 12       Transport             EUR
# 13       Transport             EUR
# 14       Transport             EUR
# 15       Transport             EUR
# 16       Transport             EUR
# 17       Transport             EUR
# 18       Transport             EUR
# 19       Transport             EUR
# 20       Transport             EUR
# 21       Chemicals             EUR
# 22       Chemicals             EUR
# 23       Chemicals             EUR
# 24       Chemicals             EUR
# 25       Chemicals             EUR
# 26       Chemicals             EUR
# 27       Chemicals             EUR
# 28       Chemicals             EUR
# 29          Cement             EUR
# 30          Cement             EUR
# 31          Cement             EUR
# 32          Cement             EUR
# 33          Cement             EUR
# 34          Cement             EUR
# 35          Cement             EUR
# 36          Cement             EUR
# 37          Cement             EUR
# 38          Cement             EUR
# 39          Cement             EUR
# 40  Other end uses             EUR
# 41  Other end uses             EUR
# 42  Other end uses             EUR
# 43  Other end uses             EUR
# 44  Other end uses             EUR
# 45  Other end uses             EUR
# 46  Other end uses             EUR
# 47  Other end uses             EUR
# 48  Other end uses             EUR
# 49  Other end uses             EUR
# 50  Other end uses             EUR
# 51  Other end uses             EUR
# 52  Other end uses             EUR
#
#                                                                                                                                 provider  \
# 0                                                     hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity
# 1             hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, at gasification plant
# 2   hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, with CCS, at gasification plant
# 3                                                                                       hydrogen production, coal gasification, with CCS
# 4                                                                                 hydrogen production, steam methane reforming, with CCS
# 5                                                                                               hydrogen supply, distributed by pipeline
# 6                                                                                 compressor assembly for transmission hydrogen pipeline
# 7                                                                                              market group for electricity, low voltage
# 8                                                     hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity
# 9             hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, at gasification plant
# 10  hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, with CCS, at gasification plant
# 11                                                                                      hydrogen production, coal gasification, with CCS
# 12                                                                                hydrogen production, steam methane reforming, with CCS
# 13                                                                                      transport, hydrogen, gaseous, lorry, unspecified
# 14                                                                                       transport, hydrogen, liquid, lorry, unspecified
# 15                                                                                              hydrogen supply, distributed by pipeline
# 16                                                                                compressor assembly for transmission hydrogen pipeline
# 17                                                                                             market group for electricity, low voltage
# 18                                                                                                           gaseous hydrogen production
# 19                                                                                                            liquid hydrogen production
# 20                                                                                                        liquid hydrogen regasification
# 21                                                    hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity
# 22            hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, at gasification plant
# 23  hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, with CCS, at gasification plant
# 24                                                                                      hydrogen production, coal gasification, with CCS
# 25                                                                                hydrogen production, steam methane reforming, with CCS
# 26                                                                                              hydrogen supply, distributed by pipeline
# 27                                                                                compressor assembly for transmission hydrogen pipeline
# 28                                                                                             market group for electricity, low voltage
# 29                                                    hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity
# 30            hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, at gasification plant
# 31  hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, with CCS, at gasification plant
# 32                                                                                      hydrogen production, coal gasification, with CCS
# 33                                                                                hydrogen production, steam methane reforming, with CCS
# 34                                                                                       transport, hydrogen, liquid, lorry, unspecified
# 35                                                                                              hydrogen supply, distributed by pipeline
# 36                                                                                compressor assembly for transmission hydrogen pipeline
# 37                                                                                             market group for electricity, low voltage
# 38                                                                                                            liquid hydrogen production
# 39                                                                                                        liquid hydrogen regasification
# 40                                                    hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity
# 41            hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, at gasification plant
# 42  hydrogen production, gaseous, 25 bar, from gasification of woody biomass in entrained flow gasifier, with CCS, at gasification plant
# 43                                                                                      hydrogen production, coal gasification, with CCS
# 44                                                                                hydrogen production, steam methane reforming, with CCS
# 45                                                                                      transport, hydrogen, gaseous, lorry, unspecified
# 46                                                                                       transport, hydrogen, liquid, lorry, unspecified
# 47                                                                                              hydrogen supply, distributed by pipeline
# 48                                                                                compressor assembly for transmission hydrogen pipeline
# 49                                                                                             market group for electricity, low voltage
# 50                                                                                                           gaseous hydrogen production
# 51                                                                                                            liquid hydrogen production
# 52                                                                                                        liquid hydrogen regasification
#
#                                     provider product  provider unit  \
# 0                          hydrogen, gaseous, 30 bar       kilogram
# 1                          hydrogen, gaseous, 25 bar       kilogram
# 2                          hydrogen, gaseous, 25 bar       kilogram
# 3                    hydrogen, gaseous, low pressure       kilogram
# 4                    hydrogen, gaseous, low pressure       kilogram
# 5                   hydrogen, gaseous, from pipeline       kilogram
# 6              compressor, for hydrogen transmission           unit
# 7                           electricity, low voltage  kilowatt hour
# 8                          hydrogen, gaseous, 30 bar       kilogram
# 9                          hydrogen, gaseous, 25 bar       kilogram
# 10                         hydrogen, gaseous, 25 bar       kilogram
# 11                   hydrogen, gaseous, low pressure       kilogram
# 12                   hydrogen, gaseous, low pressure       kilogram
# 13  transport, hydrogen, gaseous, lorry, unspecified  ton kilometer
# 14   transport, hydrogen, liquid, lorry, unspecified  ton kilometer
# 15                  hydrogen, gaseous, from pipeline       kilogram
# 16             compressor, for hydrogen transmission           unit
# 17                          electricity, low voltage  kilowatt hour
# 18                       gaseous hydrogen production           unit
# 19                        liquid hydrogen production           unit
# 20                    liquid hydrogen regasification           unit
# 21                         hydrogen, gaseous, 30 bar       kilogram
# 22                         hydrogen, gaseous, 25 bar       kilogram
# 23                         hydrogen, gaseous, 25 bar       kilogram
# 24                   hydrogen, gaseous, low pressure       kilogram
# 25                   hydrogen, gaseous, low pressure       kilogram
# 26                  hydrogen, gaseous, from pipeline       kilogram
# 27             compressor, for hydrogen transmission           unit
# 28                          electricity, low voltage  kilowatt hour
# 29                         hydrogen, gaseous, 30 bar       kilogram
# 30                         hydrogen, gaseous, 25 bar       kilogram
# 31                         hydrogen, gaseous, 25 bar       kilogram
# 32                   hydrogen, gaseous, low pressure       kilogram
# 33                   hydrogen, gaseous, low pressure       kilogram
# 34   transport, hydrogen, liquid, lorry, unspecified  ton kilometer
# 35                  hydrogen, gaseous, from pipeline       kilogram
# 36             compressor, for hydrogen transmission           unit
# 37                          electricity, low voltage  kilowatt hour
# 38                        liquid hydrogen production           unit
# 39                    liquid hydrogen regasification           unit
# 40                         hydrogen, gaseous, 30 bar       kilogram
# 41                         hydrogen, gaseous, 25 bar       kilogram
# 42                         hydrogen, gaseous, 25 bar       kilogram
# 43                   hydrogen, gaseous, low pressure       kilogram
# 44                   hydrogen, gaseous, low pressure       kilogram
# 45  transport, hydrogen, gaseous, lorry, unspecified  ton kilometer
# 46   transport, hydrogen, liquid, lorry, unspecified  ton kilometer
# 47                  hydrogen, gaseous, from pipeline       kilogram
# 48             compressor, for hydrogen transmission           unit
# 49                          electricity, low voltage  kilowatt hour
# 50                       gaseous hydrogen production           unit
# 51                        liquid hydrogen production           unit
# 52                    liquid hydrogen regasification           unit
#
#    provider location  \
# 0                EUR
# 1                EUR
# 2                EUR
# 3                EUR
# 4                EUR
# 5                EUR
# 6                RER
# 7                EUR
# 8                EUR
# 9                EUR
# 10               EUR
# 11               EUR
# 12               EUR
# 13               GLO
# 14               GLO
# 15               EUR
# 16               RER
# 17               EUR
# 18               EUR
# 19               EUR
# 20               EUR
# 21               EUR
# 22               EUR
# 23               EUR
# 24               EUR
# 25               EUR
# 26               EUR
# 27               RER
# 28               EUR
# 29               EUR
# 30               EUR
# 31               EUR
# 32               EUR
# 33               EUR
# 34               GLO
# 35               EUR
# 36               RER
# 37               EUR
# 38               EUR
# 39               EUR
# 40               EUR
# 41               EUR
# 42               EUR
# 43               EUR
# 44               EUR
# 45               GLO
# 46               GLO
# 47               EUR
# 48               RER
# 49               EUR
# 50               EUR
# 51               EUR
# 52               EUR
#
#                                                                                 provider key  \
# 0   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f5642d3f88144e1988b8d55200969141)
# 1   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f02dda61be444bc89a9e6f74e76b34a3)
# 2   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 482a4817f30b4f129dd66fa2bd320ebc)
# 3   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d263afe3112e4984aff3d5550d58ae3d)
# 4   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 437ba225e430480cb77fba3bbdf783ca)
# 5   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 6   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
# 7   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e987ddcd45894de6bad39af27537420a)
# 8   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f5642d3f88144e1988b8d55200969141)
# 9   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f02dda61be444bc89a9e6f74e76b34a3)
# 10  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 482a4817f30b4f129dd66fa2bd320ebc)
# 11  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d263afe3112e4984aff3d5550d58ae3d)
# 12  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 437ba225e430480cb77fba3bbdf783ca)
# 13  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 5491f64f2d1d45e0b23a7d9ff257dfed)
# 14  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 27adc2bf3f8941809df91592d422caf9)
# 15  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 16  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
# 17  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e987ddcd45894de6bad39af27537420a)
# 18  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 7bfe8d9c1286463bb56f94a31fb1b1fc)
# 19  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d578ba4611754d4fb8189c808531f292)
# 20  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 251400d84c86478796ffb3c2e2e5d154)
# 21  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f5642d3f88144e1988b8d55200969141)
# 22  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f02dda61be444bc89a9e6f74e76b34a3)
# 23  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 482a4817f30b4f129dd66fa2bd320ebc)
# 24  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d263afe3112e4984aff3d5550d58ae3d)
# 25  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 437ba225e430480cb77fba3bbdf783ca)
# 26  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 27  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
# 28  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e987ddcd45894de6bad39af27537420a)
# 29  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f5642d3f88144e1988b8d55200969141)
# 30  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f02dda61be444bc89a9e6f74e76b34a3)
# 31  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 482a4817f30b4f129dd66fa2bd320ebc)
# 32  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d263afe3112e4984aff3d5550d58ae3d)
# 33  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 437ba225e430480cb77fba3bbdf783ca)
# 34  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 27adc2bf3f8941809df91592d422caf9)
# 35  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 36  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
# 37  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e987ddcd45894de6bad39af27537420a)
# 38  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d578ba4611754d4fb8189c808531f292)
# 39  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 251400d84c86478796ffb3c2e2e5d154)
# 40  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f5642d3f88144e1988b8d55200969141)
# 41  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f02dda61be444bc89a9e6f74e76b34a3)
# 42  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 482a4817f30b4f129dd66fa2bd320ebc)
# 43  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d263afe3112e4984aff3d5550d58ae3d)
# 44  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 437ba225e430480cb77fba3bbdf783ca)
# 45  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 5491f64f2d1d45e0b23a7d9ff257dfed)
# 46  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 27adc2bf3f8941809df91592d422caf9)
# 47  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 48  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
# 49  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e987ddcd45894de6bad39af27537420a)
# 50  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 7bfe8d9c1286463bb56f94a31fb1b1fc)
# 51  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d578ba4611754d4fb8189c808531f292)
# 52  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 251400d84c86478796ffb3c2e2e5d154)
#
#     demand amount         stage               substage  \
# 0    6.916314e-01    Production  Production technology
# 1    2.041851e-01    Production  Production technology
# 2    2.896934e-06    Production  Production technology
# 3    2.586548e-06    Production  Production technology
# 4    1.041780e-01    Production  Production technology
# 5    1.000000e+00  Distribution              Transport
# 6    3.227031e-11  Distribution             Conversion
# 7    1.816554e+00  Distribution             Conversion
# 8    6.916314e-01    Production  Production technology
# 9    2.041851e-01    Production  Production technology
# 10   2.896934e-06    Production  Production technology
# 11   2.586548e-06    Production  Production technology
# 12   1.041780e-01    Production  Production technology
# 13   1.250000e-02  Distribution              Transport
# 14   2.500000e-02  Distribution              Transport
# 15   5.000000e-01  Distribution              Transport
# 16   1.613516e-11  Distribution             Conversion
# 17   9.082769e-01  Distribution             Conversion
# 18   2.500000e-01  Distribution             Conversion
# 19   2.500000e-01  Distribution             Conversion
# 20   2.500000e-01  Distribution           Reconversion
# 21   6.916314e-01    Production  Production technology
# 22   2.041851e-01    Production  Production technology
# 23   2.896934e-06    Production  Production technology
# 24   2.586548e-06    Production  Production technology
# 25   1.041780e-01    Production  Production technology
# 26   8.000000e-01  Distribution              Transport
# 27   2.581625e-11  Distribution             Conversion
# 28   1.453243e+00  Distribution             Conversion
# 29   6.916314e-01    Production  Production technology
# 30   2.041851e-01    Production  Production technology
# 31   2.896934e-06    Production  Production technology
# 32   2.586548e-06    Production  Production technology
# 33   1.041780e-01    Production  Production technology
# 34   2.000000e-02  Distribution              Transport
# 35   8.000000e-01  Distribution              Transport
# 36   2.581625e-11  Distribution             Conversion
# 37   1.453243e+00  Distribution             Conversion
# 38   2.000000e-01  Distribution             Conversion
# 39   2.000000e-01  Distribution           Reconversion
# 40   6.916314e-01    Production  Production technology
# 41   2.041851e-01    Production  Production technology
# 42   2.896934e-06    Production  Production technology
# 43   2.586548e-06    Production  Production technology
# 44   1.041780e-01    Production  Production technology
# 45   1.250000e-02  Distribution              Transport
# 46   2.500000e-02  Distribution              Transport
# 47   5.000000e-01  Distribution              Transport
# 48   1.613516e-11  Distribution             Conversion
# 49   9.082769e-01  Distribution             Conversion
# 50   2.500000e-01  Distribution             Conversion
# 51   2.500000e-01  Distribution             Conversion
# 52   2.500000e-01  Distribution           Reconversion
#
#                            component           classification rule
# 0                   PEM electrolysis  hydrogen production activity
# 1               Biomass gasification  hydrogen production activity
# 2      Biomass gasification with CCS  hydrogen production activity
# 3         Coal gasification with CCS  hydrogen production activity
# 4   Steam methane reforming with CCS  hydrogen production activity
# 5              Pipeline distribution      exact transport activity
# 6             Compression (pipeline)    pipeline compression input
# 7             Compression (pipeline)    pipeline compression input
# 8                   PEM electrolysis  hydrogen production activity
# 9               Biomass gasification  hydrogen production activity
# 10     Biomass gasification with CCS  hydrogen production activity
# 11        Coal gasification with CCS  hydrogen production activity
# 12  Steam methane reforming with CCS  hydrogen production activity
# 13                  Gaseous H2 truck      exact transport activity
# 14                   Liquid H2 truck      exact transport activity
# 15             Pipeline distribution      exact transport activity
# 16            Compression (pipeline)    pipeline compression input
# 17            Compression (pipeline)    pipeline compression input
# 18               Compression (lorry)     exact conversion activity
# 19                      Liquefaction     exact conversion activity
# 20           Hydrogen regasification         reconversion activity
# 21                  PEM electrolysis  hydrogen production activity
# 22              Biomass gasification  hydrogen production activity
# 23     Biomass gasification with CCS  hydrogen production activity
# 24        Coal gasification with CCS  hydrogen production activity
# 25  Steam methane reforming with CCS  hydrogen production activity
# 26             Pipeline distribution      exact transport activity
# 27            Compression (pipeline)    pipeline compression input
# 28            Compression (pipeline)    pipeline compression input
# 29                  PEM electrolysis  hydrogen production activity
# 30              Biomass gasification  hydrogen production activity
# 31     Biomass gasification with CCS  hydrogen production activity
# 32        Coal gasification with CCS  hydrogen production activity
# 33  Steam methane reforming with CCS  hydrogen production activity
# 34                   Liquid H2 truck      exact transport activity
# 35             Pipeline distribution      exact transport activity
# 36            Compression (pipeline)    pipeline compression input
# 37            Compression (pipeline)    pipeline compression input
# 38                      Liquefaction     exact conversion activity
# 39           Hydrogen regasification         reconversion activity
# 40                  PEM electrolysis  hydrogen production activity
# 41              Biomass gasification  hydrogen production activity
# 42     Biomass gasification with CCS  hydrogen production activity
# 43        Coal gasification with CCS  hydrogen production activity
# 44  Steam methane reforming with CCS  hydrogen production activity
# 45                  Gaseous H2 truck      exact transport activity
# 46                   Liquid H2 truck      exact transport activity
# 47             Pipeline distribution      exact transport activity
# 48            Compression (pipeline)    pipeline compression input
# 49            Compression (pipeline)    pipeline compression input
# 50               Compression (lorry)     exact conversion activity
# 51                      Liquefaction     exact conversion activity
# 52           Hydrogen regasification         reconversion activity
#            market                                          method  \
# 0         Generic  (IPCC 2021, climate change, GWP 100a, incl. H)
# 1       Transport  (IPCC 2021, climate change, GWP 100a, incl. H)
# 2       Chemicals  (IPCC 2021, climate change, GWP 100a, incl. H)
# 3          Cement  (IPCC 2021, climate change, GWP 100a, incl. H)
# 4  Other end uses  (IPCC 2021, climate change, GWP 100a, incl. H)
#
#                                     impact category       unit  total score  \
# 0  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     1.128866
# 1  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     1.250089
# 2  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     1.100230
# 3  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     1.233742
# 4  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     1.250089
#
#    Layer 1 reconstructed score  Layer 1 difference  \
# 0                     1.128866        2.953706e-09
# 1                     1.250089        2.522169e-09
# 2                     1.100230        1.246826e-09
# 3                     1.233742       -1.322844e-10
# 4                     1.250089        2.522169e-09
#
#    Layer 2 reconstructed score  Layer 2 difference
# 0                     1.128866        8.493626e-09
# 1                     1.250089        8.062089e-09
# 2                     1.100230        6.786746e-09
# 3                     1.233742        5.407636e-09
# 4                     1.250089        8.062089e-09
#        market          layer 1 group                         component  \
# 0     Generic  Production technology                  PEM electrolysis
# 1     Generic  Production technology              Biomass gasification
# 2     Generic  Production technology     Biomass gasification with CCS
# 3     Generic  Production technology        Coal gasification with CCS
# 4     Generic  Production technology  Steam methane reforming with CCS
# 5     Generic  Hydrogen distribution             Hydrogen distribution
# 6     Generic  Hydrogen distribution   Hydrogen leakage — distribution
# 7   Transport  Production technology                  PEM electrolysis
# 8   Transport  Production technology              Biomass gasification
# 9   Transport  Production technology     Biomass gasification with CCS
# 10  Transport  Production technology        Coal gasification with CCS
# 11  Transport  Production technology  Steam methane reforming with CCS
# 12  Transport  Hydrogen distribution             Hydrogen distribution
# 13  Transport  Hydrogen distribution   Hydrogen leakage — distribution
# 14  Chemicals  Production technology                  PEM electrolysis
# 15  Chemicals  Production technology              Biomass gasification
# 16  Chemicals  Production technology     Biomass gasification with CCS
# 17  Chemicals  Production technology        Coal gasification with CCS
# 18  Chemicals  Production technology  Steam methane reforming with CCS
# 19  Chemicals  Hydrogen distribution             Hydrogen distribution
#
#                  contribution type     score  share of market (%)  \
# 0     Technology excluding leakage  0.846475            74.984549
# 1     Technology excluding leakage  0.047227             4.183541
# 2     Technology excluding leakage  0.000001             0.000090
# 3     Technology excluding leakage  0.000012             0.001091
# 4     Technology excluding leakage  0.091971             8.147200
# 5   Distribution excluding leakage  0.067122             5.945985
# 6                 Hydrogen leakage  0.076058             6.737545
# 7     Technology excluding leakage  0.846475            67.713167
# 8     Technology excluding leakage  0.047227             3.777856
# 9     Technology excluding leakage  0.000001             0.000081
# 10    Technology excluding leakage  0.000012             0.000985
# 11    Technology excluding leakage  0.091971             7.357152
# 12  Distribution excluding leakage  0.154668            12.372571
# 13                Hydrogen leakage  0.109735             8.778189
# 14    Technology excluding leakage  0.846475            76.936194
# 15    Technology excluding leakage  0.047227             4.292427
# 16    Technology excluding leakage  0.000001             0.000092
# 17    Technology excluding leakage  0.000012             0.001119
# 18    Technology excluding leakage  0.091971             8.359249
# 19  Distribution excluding leakage  0.053698             4.880594
#
#     physical amount physical unit  \
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
# 5               NaN           NaN
# 6          0.006914      kilogram
# 7               NaN           NaN
# 8               NaN           NaN
# 9               NaN           NaN
# 10              NaN           NaN
# 11              NaN           NaN
# 12              NaN           NaN
# 13         0.009976      kilogram
# 14              NaN           NaN
# 15              NaN           NaN
# 16              NaN           NaN
# 17              NaN           NaN
# 18              NaN           NaN
# 19              NaN           NaN
#
#                                             method  \
# 0   (IPCC 2021, climate change, GWP 100a, incl. H)
# 1   (IPCC 2021, climate change, GWP 100a, incl. H)
# 2   (IPCC 2021, climate change, GWP 100a, incl. H)
# 3   (IPCC 2021, climate change, GWP 100a, incl. H)
# 4   (IPCC 2021, climate change, GWP 100a, incl. H)
# 5   (IPCC 2021, climate change, GWP 100a, incl. H)
# 6   (IPCC 2021, climate change, GWP 100a, incl. H)
# 7   (IPCC 2021, climate change, GWP 100a, incl. H)
# 8   (IPCC 2021, climate change, GWP 100a, incl. H)
# 9   (IPCC 2021, climate change, GWP 100a, incl. H)
# 10  (IPCC 2021, climate change, GWP 100a, incl. H)
# 11  (IPCC 2021, climate change, GWP 100a, incl. H)
# 12  (IPCC 2021, climate change, GWP 100a, incl. H)
# 13  (IPCC 2021, climate change, GWP 100a, incl. H)
# 14  (IPCC 2021, climate change, GWP 100a, incl. H)
# 15  (IPCC 2021, climate change, GWP 100a, incl. H)
# 16  (IPCC 2021, climate change, GWP 100a, incl. H)
# 17  (IPCC 2021, climate change, GWP 100a, incl. H)
# 18  (IPCC 2021, climate change, GWP 100a, incl. H)
# 19  (IPCC 2021, climate change, GWP 100a, incl. H)
#
#                                      impact category       unit
# 0   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 1   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 2   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 3   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 4   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 5   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 6   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 7   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 8   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 9   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 10  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 11  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 12  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 13  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 14  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 15  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 16  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 17  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 18  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 19  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
#     market                     technology              input group  \
# 0   Cement           Biomass gasification        Biomass feedstock
# 1   Cement           Biomass gasification           Infrastructure
# 2   Cement           Biomass gasification   Other direct emissions
# 3   Cement           Biomass gasification                    Water
# 4   Cement  Biomass gasification with CCS        Biomass feedstock
# 5   Cement  Biomass gasification with CCS  CO2 capture and storage
# 6   Cement  Biomass gasification with CCS           Infrastructure
# 7   Cement  Biomass gasification with CCS   Other direct emissions
# 8   Cement  Biomass gasification with CCS                    Water
# 9   Cement     Coal gasification with CCS  CO2 capture and storage
# 10  Cement     Coal gasification with CCS              Electricity
# 11  Cement     Coal gasification with CCS         Fossil feedstock
# 12  Cement     Coal gasification with CCS           Infrastructure
# 13  Cement     Coal gasification with CCS   Other direct emissions
# 14  Cement     Coal gasification with CCS      Other raw materials
# 15  Cement     Coal gasification with CCS       Transport services
# 16  Cement     Coal gasification with CCS          Waste treatment
# 17  Cement     Coal gasification with CCS                    Water
# 18  Cement               PEM electrolysis              Electricity
# 19  Cement               PEM electrolysis           Infrastructure
#
#          contribution type         score  score per kg H2  \
# 0           Upstream input  4.545241e-02         1.233742
# 1           Upstream input  6.707240e-04         1.233742
# 2   Other direct emissions  0.000000e+00         1.233742
# 3           Upstream input  1.103422e-03         1.233742
# 4           Upstream input  6.448689e-07         1.233742
# 5           Upstream input  3.432639e-07         1.233742
# 6           Upstream input  9.516086e-09         1.233742
# 7   Other direct emissions  0.000000e+00         1.233742
# 8           Upstream input  1.566693e-08         1.233742
# 9           Upstream input  2.392662e-07         1.233742
# 10          Upstream input  4.436421e-07         1.233742
# 11          Upstream input  4.950955e-06         1.233742
# 12          Upstream input  1.122554e-07         1.233742
# 13  Other direct emissions  6.414639e-06         1.233742
# 14          Upstream input  4.310283e-08         1.233742
# 15          Upstream input  4.466293e-08         1.233742
# 16          Upstream input  2.939841e-09         1.233742
# 17          Upstream input  6.473034e-08         1.233742
# 18          Upstream input  8.101135e-01         1.233742
# 19          Upstream input  3.537302e-02         1.233742
#
#     share of market (%)                                          method  \
# 0          3.684111e+00  (IPCC 2021, climate change, GWP 100a, incl. H)
# 1          5.436503e-02  (IPCC 2021, climate change, GWP 100a, incl. H)
# 2          0.000000e+00  (IPCC 2021, climate change, GWP 100a, incl. H)
# 3          8.943702e-02  (IPCC 2021, climate change, GWP 100a, incl. H)
# 4          5.226936e-05  (IPCC 2021, climate change, GWP 100a, incl. H)
# 5          2.782299e-05  (IPCC 2021, climate change, GWP 100a, incl. H)
# 6          7.713192e-07  (IPCC 2021, climate change, GWP 100a, incl. H)
# 7          0.000000e+00  (IPCC 2021, climate change, GWP 100a, incl. H)
# 8          1.269871e-06  (IPCC 2021, climate change, GWP 100a, incl. H)
# 9          1.939354e-05  (IPCC 2021, climate change, GWP 100a, incl. H)
# 10         3.595907e-05  (IPCC 2021, climate change, GWP 100a, incl. H)
# 11         4.012959e-04  (IPCC 2021, climate change, GWP 100a, incl. H)
# 12         9.098774e-06  (IPCC 2021, climate change, GWP 100a, incl. H)
# 13         5.199337e-04  (IPCC 2021, climate change, GWP 100a, incl. H)
# 14         3.493667e-06  (IPCC 2021, climate change, GWP 100a, incl. H)
# 15         3.620120e-06  (IPCC 2021, climate change, GWP 100a, incl. H)
# 16         2.382866e-07  (IPCC 2021, climate change, GWP 100a, incl. H)
# 17         5.246668e-06  (IPCC 2021, climate change, GWP 100a, incl. H)
# 18         6.566314e+01  (IPCC 2021, climate change, GWP 100a, incl. H)
# 19         2.867133e+00  (IPCC 2021, climate change, GWP 100a, incl. H)
#
#                                      impact category       unit
# 0   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 1   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 2   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 3   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 4   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 5   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 6   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 7   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 8   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 9   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 10  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 11  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 12  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 13  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 14  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 15  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 16  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 17  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 18  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 19  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
#        market      substage                                     process  \
# 0     Generic     Transport                       Pipeline distribution
# 1     Generic    Conversion                      Compression (pipeline)
# 2     Generic    Conversion                      Compression (pipeline)
# 3     Generic     Transport    Hydrogen leakage — Pipeline distribution
# 4   Transport     Transport                            Gaseous H2 truck
# 5   Transport     Transport         Hydrogen leakage — Gaseous H2 truck
# 6   Transport     Transport                             Liquid H2 truck
# 7   Transport     Transport          Hydrogen leakage — Liquid H2 truck
# 8   Transport     Transport                       Pipeline distribution
# 9   Transport    Conversion                      Compression (pipeline)
# 10  Transport    Conversion                      Compression (pipeline)
# 11  Transport     Transport    Hydrogen leakage — Pipeline distribution
# 12  Transport    Conversion                         Compression (lorry)
# 13  Transport    Conversion      Hydrogen leakage — Compression (lorry)
# 14  Transport    Conversion                                Liquefaction
# 15  Transport    Conversion             Hydrogen leakage — Liquefaction
# 16  Transport  Reconversion                     Hydrogen regasification
# 17  Transport  Reconversion  Hydrogen leakage — Hydrogen regasification
# 18  Chemicals     Transport                       Pipeline distribution
# 19  Chemicals    Conversion                      Compression (pipeline)
#
#                                                                                  process key  \
# 0   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 1   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
# 2   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e987ddcd45894de6bad39af27537420a)
# 3   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 4   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 5491f64f2d1d45e0b23a7d9ff257dfed)
# 5   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 5491f64f2d1d45e0b23a7d9ff257dfed)
# 6   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 27adc2bf3f8941809df91592d422caf9)
# 7   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 27adc2bf3f8941809df91592d422caf9)
# 8   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 9   (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
# 10  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e987ddcd45894de6bad39af27537420a)
# 11  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 12  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 7bfe8d9c1286463bb56f94a31fb1b1fc)
# 13  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 7bfe8d9c1286463bb56f94a31fb1b1fc)
# 14  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d578ba4611754d4fb8189c808531f292)
# 15  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d578ba4611754d4fb8189c808531f292)
# 16  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 251400d84c86478796ffb3c2e2e5d154)
# 17  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 251400d84c86478796ffb3c2e2e5d154)
# 18  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 6ea125a888204d43a15ea440c00422b7)
# 19  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, d7e9a9064e344c9093664d645c263694)
#
#             contribution type     score  share of market (%)  physical amount  \
# 0   Process excluding leakage  0.019959             1.768074              NaN
# 1   Process excluding leakage  0.000009             0.000796              NaN
# 2   Process excluding leakage  0.047154             4.177115              NaN
# 3            Hydrogen leakage  0.076058             6.737545         0.006914
# 4   Process excluding leakage  0.007788             0.623026              NaN
# 5            Hydrogen leakage  0.000687             0.054996         0.000062
# 6   Process excluding leakage  0.016011             1.280793              NaN
# 7            Hydrogen leakage  0.004469             0.357475         0.000406
# 8   Process excluding leakage  0.009980             0.798310              NaN
# 9   Process excluding leakage  0.000004             0.000359              NaN
# 10  Process excluding leakage  0.023577             1.886026              NaN
# 11           Hydrogen leakage  0.038029             3.042097         0.003457
# 12  Process excluding leakage  0.009197             0.735735              NaN
# 13           Hydrogen leakage  0.008250             0.659953         0.000750
# 14  Process excluding leakage  0.079111             6.328400              NaN
# 15           Hydrogen leakage  0.044550             3.563746         0.004050
# 16  Process excluding leakage  0.009000             0.719920              NaN
# 17           Hydrogen leakage  0.013750             1.099922         0.001250
# 18  Process excluding leakage  0.015967             1.451274              NaN
# 19  Process excluding leakage  0.000007             0.000654              NaN
#
#    physical unit                                          method  \
# 0            NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 1            NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 2            NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 3       kilogram  (IPCC 2021, climate change, GWP 100a, incl. H)
# 4            NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 5       kilogram  (IPCC 2021, climate change, GWP 100a, incl. H)
# 6            NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 7       kilogram  (IPCC 2021, climate change, GWP 100a, incl. H)
# 8            NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 9            NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 10           NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 11      kilogram  (IPCC 2021, climate change, GWP 100a, incl. H)
# 12           NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 13      kilogram  (IPCC 2021, climate change, GWP 100a, incl. H)
# 14           NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 15      kilogram  (IPCC 2021, climate change, GWP 100a, incl. H)
# 16           NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 17      kilogram  (IPCC 2021, climate change, GWP 100a, incl. H)
# 18           NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
# 19           NaN  (IPCC 2021, climate change, GWP 100a, incl. H)
#
#                                      impact category       unit
# 0   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 1   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 2   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 3   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 4   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 5   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 6   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 7   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 8   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 9   climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 10  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 11  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 12  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 13  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 14  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 15  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 16  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 17  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 18  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq
# 19  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq

# %%
stage_analysis.plot_stage_layer1(stage_layer1_df, market_order)
# stage_analysis.plot_production_layer2(production_input_groups_df, market_order)
stage_analysis.plot_distribution_layer2(distribution_processes_df, market_order)

# %% [markdown]
# ## 11. Export numerical results
#
# The exports include the selection audit, complete EF 3.1, premise hydrogen-GWP and CED scores, comparisons with the generic RER market, the EF 3.1 spider ratios, selected-impact hotspot process-group shares and reconciliation, premise-GWP full-system process contributions, and the Layer 1, Layer 2, classification-audit, and reconciliation tables.

# %%
output_dir = Path.cwd() if Path.cwd().name == "dev" else Path.cwd() / "dev"
output_dir.mkdir(parents=True, exist_ok=True)
exports = {
    "selection": (selection_df, output_dir / "hydrogen_markets_europe_selection.csv"),
    "scores": (scores_df, output_dir / "hydrogen_markets_europe_lcia_scores_per_kg.csv"),
    "RER comparison": (comparison_rer_df, output_dir / "hydrogen_markets_europe_vs_generic_RER.csv"),
    "EF 3.1 spider ratios": (spider_ratio_df, output_dir / "hydrogen_markets_europe_ef31_ratios_vs_generic_RER.csv"),
    "Hotspot process groups": (hotspot_process_group_df, output_dir / "hydrogen_markets_europe_hotspot_process_groups.csv"),
    "Hotspot reconciliation": (hotspot_reconciliation_df, output_dir / "hydrogen_markets_europe_hotspot_reconciliation.csv"),
    "contributions": (contributions_df, output_dir / "hydrogen_markets_europe_lcia_process_contributions.csv"),
    "Stage Layer 1": (stage_layer1_df, output_dir / "hydrogen_markets_europe_stage_layer1.csv"),
    "Production inputs detailed": (production_inputs_detailed_df, output_dir / "hydrogen_markets_europe_production_inputs_detailed.csv"),
    "Production input groups": (production_input_groups_df, output_dir / "hydrogen_markets_europe_production_input_groups.csv"),
    "Distribution processes": (distribution_processes_df, output_dir / "hydrogen_markets_europe_distribution_processes.csv"),
    "Stage classification audit": (stage_classification_audit_df, output_dir / "hydrogen_markets_europe_stage_classification_audit.csv"),
    "Stage reconciliation": (stage_reconciliation_df, output_dir / "hydrogen_markets_europe_stage_reconciliation.csv"),
}
#for label, (dataframe, path) in exports.items():
    #dataframe.to_csv(path, index=False)
    #print(f"{label:28s}: {path.resolve()}")

#display(scores_df.sort_values(["impact category", "market"]))

# %% [markdown]
# ## Interpretation checklist
#
# 1. Confirm the selection table before interpreting results, especially the `RER` generic versus `EUR` sector geography.
# 2. Use `Generic (RER)` as the sole baseline for every sector comparison.
# 3. Compare scores only within the same impact category and unit; do not add unnormalized midpoint results.
# 4. Treat missing sector markets as scenario results: they indicate no positive modeled hydrogen demand for that sector/region combination.
# 5. Inspect negative contributions and shares above 100%; these represent credits or offsetting burdens and are not automatically errors.
# 6. Use the premise GWP100 result to capture hydrogen emissions to air; the standard EF 3.1 climate-change category is retained separately.
# 7. Interpret aggregate CED non-renewable and renewable results separately; both are reported in MJ-Eq per kg H2.
# 8. Read the EF 3.1 spider diagram as ratios: 1 equals the Generic (RER) score, values above 1 are higher, and values below 1 are lower.
# 9. Use the relative Layer 1 shares to compare production technologies with aggregated hydrogen distribution. Use the absolute Layer 2 scores to inspect production inputs and the transport, conversion, and reconversion processes; verify both against the reconciliation table.

# %%
# Compare the exact steel-specific low-pressure gaseous hydrogen market across all
# available regional locations, excluding the aggregate WORLD market.
STEEL_MARKET_NAME = "market for hydrogen, gaseous, low pressure, for steel"
EXCLUDED_STEEL_LOCATION = "WORLD"

steel_region_activities = sorted(
    [
        activity for activity in database
        if activity.get("name") == STEEL_MARKET_NAME
        and activity.get("reference product") == REFERENCE_PRODUCT
        and activity.get("unit") == UNIT
        and str(activity.get("location", "")).upper() != EXCLUDED_STEEL_LOCATION
    ],
    key=lambda activity: (activity.get("location", ""), str(activity.key)),
)
if not steel_region_activities:
    raise LookupError(
        f"No exact {STEEL_MARKET_NAME!r} activities outside "
        f"{EXCLUDED_STEEL_LOCATION!r} were found in {DATABASE!r}."
    )

location_counts = pd.Series(
    [activity.get("location") for activity in steel_region_activities]
).value_counts()
duplicate_locations = location_counts[location_counts > 1].index.tolist()
if duplicate_locations:
    raise LookupError(
        "Expected one exact steel hydrogen market per region; duplicate locations: "
        + ", ".join(duplicate_locations)
    )

steel_region_selected = {
    activity.get("location"): activity for activity in steel_region_activities
}
steel_region_order = list(steel_region_selected)
steel_region_selection_df = pd.DataFrame([
    {
        "region": region,
        "name": activity.get("name"),
        "reference product": activity.get("reference product"),
        "unit": activity.get("unit"),
        "database key": activity.key,
    }
    for region, activity in steel_region_selected.items()
])
print(
    f"Selected {len(steel_region_selected)} regional steel hydrogen markets; "
    f"excluded {EXCLUDED_STEEL_LOCATION}."
)
display(steel_region_selection_df)

# Calculate the premise GWP score required by the process-group analysis.
steel_region_score_records = []
for region, activity in steel_region_selected.items():
    lca = bc.LCA({activity: FUNCTIONAL_UNIT_KG}, PREMISE_GWP_METHOD)
    lca.lci()
    lca.lcia()
    steel_region_score_records.append({
        "market": region,
        "market name": activity.get("name"),
        "location": activity.get("location"),
        "impact category": impact_category_label(PREMISE_GWP_METHOD),
        "indicator": PREMISE_GWP_METHOD[-1],
        "method": PREMISE_GWP_METHOD,
        "unit": method_units[PREMISE_GWP_METHOD],
        "score per kg H2": float(lca.score),
    })
    print(f"Finished {region}")

steel_region_scores_df = pd.DataFrame(steel_region_score_records)
steel_region_stage_results = stage_analysis.analyze_hydrogen_life_cycle_stages(
    selected=steel_region_selected,
    market_order=steel_region_order,
    method=PREMISE_GWP_METHOD,
    functional_unit=FUNCTIONAL_UNIT_KG,
    scores_df=steel_region_scores_df,
    impact_category=impact_category_label(PREMISE_GWP_METHOD),
    unit=method_units[PREMISE_GWP_METHOD],
    reconciliation_rtol=1e-5,
)

steel_region_layer1_df = steel_region_stage_results["layer1"]
steel_region_distribution_df = steel_region_stage_results["distribution processes"]
steel_region_reconciliation_df = steel_region_stage_results["reconciliation"]
display(steel_region_reconciliation_df)

# First: production technologies versus aggregated distribution (relative shares).
stage_analysis.plot_stage_layer1(steel_region_layer1_df, steel_region_order)

# Second: distribution only, split into transport, conversion, and reconversion processes.
stage_analysis.plot_distribution_layer2(
    steel_region_distribution_df,
    steel_region_order,
)
# Out:
# Selected 5 regional steel hydrogen markets; excluded WORLD.
#   region                                                   name  \
# 0    CAZ  market for hydrogen, gaseous, low pressure, for steel
# 1    IND  market for hydrogen, gaseous, low pressure, for steel
# 2    MEA  market for hydrogen, gaseous, low pressure, for steel
# 3    OAS  market for hydrogen, gaseous, low pressure, for steel
# 4    USA  market for hydrogen, gaseous, low pressure, for steel
#
#                  reference product      unit  \
# 0  hydrogen, gaseous, low pressure  kilogram
# 1  hydrogen, gaseous, low pressure  kilogram
# 2  hydrogen, gaseous, low pressure  kilogram
# 3  hydrogen, gaseous, low pressure  kilogram
# 4  hydrogen, gaseous, low pressure  kilogram
#
#                                                                                database key
# 0  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 7b6a8482514f404aa01fcb576c677a40)
# 1  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 1860fc108c3541a7991e0b59ec355cf3)
# 2  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f1aca998b8764444a8beabc41f57eb04)
# 3  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 8301bfe06dac450483dc44db816ed140)
# 4  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, f9606fc22fd64fe396847e02d1cf4be1)
# Finished CAZ
# Finished IND
# Finished MEA
# Finished OAS
# Finished USA
#   market                                          method  \
# 0    CAZ  (IPCC 2021, climate change, GWP 100a, incl. H)
# 1    IND  (IPCC 2021, climate change, GWP 100a, incl. H)
# 2    MEA  (IPCC 2021, climate change, GWP 100a, incl. H)
# 3    OAS  (IPCC 2021, climate change, GWP 100a, incl. H)
# 4    USA  (IPCC 2021, climate change, GWP 100a, incl. H)
#
#                                     impact category       unit  total score  \
# 0  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     0.917348
# 1  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     3.801606
# 2  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     1.310313
# 3  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     1.645547
# 4  climate change — GWP 100a, incl. H (premise_gwp)  kg CO2-Eq     0.883368
#
#    Layer 1 reconstructed score  Layer 1 difference  \
# 0                     0.917348        2.112282e-08
# 1                     3.801606       -1.194582e-07
# 2                     1.310313        3.444788e-08
# 3                     1.645547        3.779300e-08
# 4                     0.883368       -4.490782e-09
#
#    Layer 2 reconstructed score  Layer 2 difference
# 0                     0.917348        2.107082e-08
# 1                     3.801606       -1.041211e-07
# 2                     1.310313        3.939262e-08
# 3                     1.645547        5.039632e-08
# 4                     0.883368       -1.642830e-09

# %%
# Combined REMIND process-group CA: retain individual production technologies and
# replace aggregated distribution with the route-level categories used above.
REMIND_DISTRIBUTION_ROUTES = {
    "Compressed gas truck": "#4C78A8",
    "Pipeline": "#59A14F",
    "Liquid hydrogen truck": "#F28E2B",
    "Ammonia shipping": "#B07AA1",
    "Shared distribution leakage": "#D62728",
}

def distribution_route(process):
    """Map each Layer-2 distribution process to a visible route."""
    text = str(process).lower()
    if "ammonia" in text:
        return "Ammonia shipping"
    if any(term in text for term in ("liquid h2", "liquefaction", "regasification")):
        return "Liquid hydrogen truck"
    if "pipeline" in text:
        return "Pipeline"
    if any(term in text for term in ("gaseous h2 truck", "lorry")):
        return "Compressed gas truck"
    if "leakage" in text and "market" in text:
        return "Shared distribution leakage"
    raise ValueError(f"Unmapped distribution process: {process!r}")

# Keep only the technology rows from Layer 1; the aggregated distribution rows
# are replaced below by route totals calculated from the detailed Layer-2 table.
remind_production_df = steel_region_layer1_df.loc[
    steel_region_layer1_df["layer 1 group"].eq("Production technology")
].copy()
remind_distribution_routes_df = steel_region_distribution_df.copy()
remind_distribution_routes_df["component"] = (
    remind_distribution_routes_df["process"].map(distribution_route)
)
remind_distribution_routes_df = (
    remind_distribution_routes_df.groupby(["market", "component"], as_index=False)["score"]
    .sum()
)
remind_distribution_routes_df["layer 1 group"] = "Distribution route"

remind_market_totals = (
    steel_region_scores_df.set_index("market")["score per kg H2"]
)
remind_distribution_routes_df["share of market (%)"] = (
    100.0
    * remind_distribution_routes_df["score"]
    / remind_distribution_routes_df["market"].map(remind_market_totals)
)

steel_region_disaggregated_layer1_df = pd.concat(
    [
        remind_production_df[["market", "layer 1 group", "component", "score", "share of market (%)"]],
        remind_distribution_routes_df[["market", "layer 1 group", "component", "score", "share of market (%)"]],
    ],
    ignore_index=True,
)

# The disaggregated components must still reconstruct the original market LCIA score.
remind_reconstructed = (
    steel_region_disaggregated_layer1_df.groupby("market")["score"]
    .sum()
    .reindex(steel_region_order)
)
if not np.allclose(
    remind_reconstructed.to_numpy(),
    remind_market_totals.reindex(steel_region_order).to_numpy(),
    rtol=1e-5,
    atol=1e-12,
):
    raise AssertionError(
        "Production technologies plus disaggregated distribution routes "
        "do not reconstruct the REMIND steel-market scores."
    )

remind_component_colors = stage_analysis.stage_layer1_color_map(
    remind_production_df
)
remind_component_colors.update(REMIND_DISTRIBUTION_ROUTES)
fig, ax = plt.subplots(
    figsize=(16, max(6, 0.75 * len(steel_region_order) + 2))
)
stage_analysis._plot_signed_stacks(
    ax,
    steel_region_disaggregated_layer1_df,
    steel_region_order,
    "component",
    remind_component_colors,
    value_column="share of market (%)",
    xlabel="Contribution to total premise-GWP score (%)",
    label_threshold=3.0,
    value_format="{:.1f}%",
)
ax.set_title(
    "Process group CA — REMIND hydrogen production technologies and "
    "disaggregated distribution routes"
)
ax.legend(
    title="Production technology or distribution route",
    bbox_to_anchor=(1.01, 1),
    loc="upper left",
    frameon=False,
)
fig.tight_layout()
plt.show()

display(steel_region_disaggregated_layer1_df)
# Out:
#    market          layer 1 group                         component  \
# 0     CAZ  Production technology                  PEM electrolysis
# 1     CAZ  Production technology              Biomass gasification
# 2     CAZ  Production technology     Biomass gasification with CCS
# 3     CAZ  Production technology        Coal gasification with CCS
# 4     CAZ  Production technology  Steam methane reforming with CCS
# 5     IND  Production technology                  PEM electrolysis
# 6     IND  Production technology              Biomass gasification
# 7     IND  Production technology     Biomass gasification with CCS
# 8     IND  Production technology        Coal gasification with CCS
# 9     IND  Production technology           Steam methane reforming
# 10    IND  Production technology  Steam methane reforming with CCS
# 11    MEA  Production technology                  PEM electrolysis
# 12    MEA  Production technology              Biomass gasification
# 13    MEA  Production technology     Biomass gasification with CCS
# 14    MEA  Production technology        Coal gasification with CCS
# 15    MEA  Production technology  Steam methane reforming with CCS
# 16    OAS  Production technology                  PEM electrolysis
# 17    OAS  Production technology              Biomass gasification
# 18    OAS  Production technology     Biomass gasification with CCS
# 19    OAS  Production technology        Coal gasification with CCS
# 20    OAS  Production technology  Steam methane reforming with CCS
# 21    USA  Production technology                  PEM electrolysis
# 22    USA  Production technology              Biomass gasification
# 23    USA  Production technology     Biomass gasification with CCS
# 24    USA  Production technology        Coal gasification with CCS
# 25    USA  Production technology  Steam methane reforming with CCS
# 26    CAZ     Distribution route             Liquid hydrogen truck
# 27    CAZ     Distribution route                          Pipeline
# 28    IND     Distribution route                  Ammonia shipping
# 29    IND     Distribution route                          Pipeline
# 30    MEA     Distribution route             Liquid hydrogen truck
# 31    MEA     Distribution route                          Pipeline
# 32    OAS     Distribution route             Liquid hydrogen truck
# 33    OAS     Distribution route                          Pipeline
# 34    USA     Distribution route             Liquid hydrogen truck
# 35    USA     Distribution route                          Pipeline
#
#            score  share of market (%)
# 0   1.123376e-01            12.245899
# 1   2.609093e-03             0.284417
# 2   5.343076e-01            58.244782
# 3   1.402867e-05             0.001529
# 4   5.140216e-02             5.603341
# 5   1.523843e+00            40.084188
# 6   1.663428e-06             0.000044
# 7   5.203915e-04             0.013689
# 8   2.525175e-03             0.066424
# 9   1.032476e-02             0.271589
# 10  9.260322e-03             0.243590
# 11  4.721437e-01            36.032895
# 12  8.345971e-07             0.000064
# 13  2.398271e-01            18.303041
# 14  5.321360e-03             0.406114
# 15  3.643413e-01            27.805669
# 16  1.254649e+00            76.245075
# 17  2.564686e-03             0.155856
# 18  6.561236e-02             3.987267
# 19  4.196604e-06             0.000255
# 20  5.196679e-02             3.158024
# 21  2.945237e-01            33.341007
# 22  3.625795e-03             0.410451
# 23  3.671454e-01            41.562011
# 24  2.081241e-06             0.000236
# 25  1.528961e-02             1.730832
# 26  1.147219e-01            12.505815
# 27  1.019561e-01            11.114219
# 28  2.143461e+00            56.383041
# 29  1.116696e-01             2.937433
# 30  1.213090e-01             9.258021
# 31  1.073697e-01             8.194199
# 32  1.466991e-01             8.914910
# 33  1.240515e-01             7.538615
# 34  1.061661e-01            12.018341
# 35  9.661502e-02            10.937123

# %%
# Diagnose the high ammonia-cracking GWP contribution by scoring every direct
# technosphere input and direct characterized emission at the market demand.
AMMONIA_CRACKING_COMPONENT = "Ammonia cracking"
TOP_CRACKING_INPUTS = 10

steel_region_audit_df = steel_region_stage_results["classification audit"]
ammonia_cracking_audit_df = steel_region_audit_df.loc[
    steel_region_audit_df["component"].eq(AMMONIA_CRACKING_COMPONENT)
].copy()
if ammonia_cracking_audit_df.empty:
    raise LookupError("No ammonia-cracking branches were found in the selected steel markets.")

cracking_cf_lookup = stage_analysis._method_cf_lookup(PREMISE_GWP_METHOD)
cracking_input_records = []
cracking_total_records = []

for _, branch in ammonia_cracking_audit_df.iterrows():
    market = branch["market"]
    cracker = bd.get_activity(branch["provider key"])
    cracking_demand = float(branch["demand amount"])
    reference_output = stage_analysis._reference_output_amount(cracker)
    scale = cracking_demand / reference_output
    scorer = stage_analysis._DemandScorer(
        steel_region_selected[market], PREMISE_GWP_METHOD
    )
    cracking_total_records.append({
        "market": market,
        "cracking activity": cracker.get("name"),
        "cracking location": cracker.get("location"),
        "cracking demand": cracking_demand,
        "cracking demand unit": cracker.get("unit"),
        "cracking GWP score": scorer.score(cracker, cracking_demand),
    })

    for exchange in cracker.technosphere():
        provider = exchange.input
        input_demand = scale * float(exchange.get("amount", 0.0))
        cracking_input_records.append({
            "market": market,
            "input type": "Technosphere",
            "input process": provider.get("name"),
            "input product or flow": provider.get("reference product"),
            "input location": provider.get("location"),
            "input amount": input_demand,
            "input unit": provider.get("unit"),
            "GWP score": scorer.score(provider, input_demand),
        })

    for exchange in cracker.biosphere():
        flow = exchange.input
        flow_amount = scale * float(exchange.get("amount", 0.0))
        characterization_factor = cracking_cf_lookup.get(int(flow.id), 0.0)
        cracking_input_records.append({
            "market": market,
            "input type": "Direct biosphere",
            "input process": f"Direct emission — {flow.get('name')}",
            "input product or flow": flow.get("name"),
            "input location": "biosphere",
            "input amount": flow_amount,
            "input unit": flow.get("unit"),
            "GWP score": flow_amount * characterization_factor,
        })

ammonia_cracking_inputs_df = pd.DataFrame(cracking_input_records)
ammonia_cracking_totals_df = (
    pd.DataFrame(cracking_total_records)
    .groupby("market", as_index=False)
    .agg({
        "cracking activity": "first",
        "cracking location": "first",
        "cracking demand": "sum",
        "cracking demand unit": "first",
        "cracking GWP score": "sum",
    })
)
cracking_total_lookup = ammonia_cracking_totals_df.set_index("market")["cracking GWP score"]
market_score_lookup = steel_region_scores_df.set_index("market")["score per kg H2"]
ammonia_cracking_inputs_df["share of cracking GWP (%)"] = (
    100.0
    * ammonia_cracking_inputs_df["GWP score"]
    / ammonia_cracking_inputs_df["market"].map(cracking_total_lookup)
)
ammonia_cracking_inputs_df["share of market GWP (%)"] = (
    100.0
    * ammonia_cracking_inputs_df["GWP score"]
    / ammonia_cracking_inputs_df["market"].map(market_score_lookup)
)
ammonia_cracking_inputs_df["absolute GWP score"] = (
    ammonia_cracking_inputs_df["GWP score"].abs()
)
ammonia_cracking_inputs_df["rank within market"] = (
    ammonia_cracking_inputs_df.groupby("market")["absolute GWP score"]
    .rank(method="dense", ascending=False)
    .astype(int)
)

# Reconcile direct inputs plus direct emissions against the complete cracking activity.
cracking_breakdown_sum = (
    ammonia_cracking_inputs_df.groupby("market")["GWP score"]
    .sum()
    .reindex(cracking_total_lookup.index)
)
ammonia_cracking_reconciliation_df = pd.DataFrame({
    "cracking GWP score": cracking_total_lookup,
    "input breakdown GWP score": cracking_breakdown_sum,
})
ammonia_cracking_reconciliation_df["difference"] = (
    ammonia_cracking_reconciliation_df["input breakdown GWP score"]
    - ammonia_cracking_reconciliation_df["cracking GWP score"]
)
if not np.allclose(
    ammonia_cracking_reconciliation_df["difference"],
    0.0,
    rtol=1e-5,
    atol=1e-10,
):
    raise AssertionError("The ammonia-cracking input breakdown does not reconcile.")

ammonia_cracking_ranked_df = (
    ammonia_cracking_inputs_df.sort_values(
        ["market", "absolute GWP score"], ascending=[True, False]
    )
    .drop(columns="absolute GWP score")
)
display(ammonia_cracking_totals_df)
display(ammonia_cracking_reconciliation_df.reset_index())
display(
    ammonia_cracking_ranked_df.loc[
        ammonia_cracking_ranked_df["rank within market"] <= TOP_CRACKING_INPUTS
    ]
)

# Plot the globally most important direct inputs; smaller inputs remain in Other inputs.
top_cracking_inputs = (
    ammonia_cracking_inputs_df.groupby("input process")["absolute GWP score"]
    .sum()
    .nlargest(TOP_CRACKING_INPUTS)
    .index
)
ammonia_cracking_plot_df = ammonia_cracking_inputs_df.copy()
ammonia_cracking_plot_df["component"] = ammonia_cracking_plot_df["input process"].where(
    ammonia_cracking_plot_df["input process"].isin(top_cracking_inputs),
    "Other inputs",
)
ammonia_cracking_plot_df = (
    ammonia_cracking_plot_df.groupby(["market", "component"], as_index=False)["GWP score"]
    .sum()
)
cracking_market_order = [
    market for market in steel_region_order
    if market in ammonia_cracking_plot_df["market"].unique()
]
cracking_components = ammonia_cracking_plot_df["component"].drop_duplicates().tolist()
cracking_palette = plt.get_cmap("tab20")
cracking_colors = {
    component: cracking_palette(i % cracking_palette.N)
    for i, component in enumerate(cracking_components)
}
fig, ax = plt.subplots(
    figsize=(14, max(5, 0.72 * len(cracking_market_order) + 2))
)
stage_analysis._plot_signed_stacks(
    ax,
    ammonia_cracking_plot_df,
    cracking_market_order,
    "component",
    cracking_colors,
    value_column="GWP score",
    xlabel=f"Ammonia-cracking contribution ({method_units[PREMISE_GWP_METHOD]} / kg H2 market)",
    label_threshold=None,
    value_format="{:.2e}",
)
ax.set_title("Ammonia cracking — highest-impact direct inputs in premise-GWP")
ax.legend(
    title="Direct input or emission",
    bbox_to_anchor=(1.01, 1),
    loc="upper left",
    frameon=False,
)
fig.tight_layout()
plt.show()
# Out:
#   market cracking activity cracking location  cracking demand  \
# 0    IND  ammonia cracking               IND            2.301
#
#   cracking demand unit  cracking GWP score
# 0                 unit            1.908571
#   market  cracking GWP score  input breakdown GWP score    difference
# 0    IND            1.908571                   1.908571 -1.332268e-15
#   market    input type                                        input process  \
# 0    IND  Technosphere           market for hydrogen, gaseous, low pressure
# 2    IND  Technosphere                market for chemical factory, organics
# 3    IND  Technosphere         market group for electricity, medium voltage
# 1    IND  Technosphere  market for liquid storage tank, chemicals, organics
#
#                       input product or flow input location  input amount  \
# 0           hydrogen, gaseous, low pressure            IND  8.053500e-01
# 2                chemical factory, organics            GLO  5.478571e-09
# 3               electricity, medium voltage            IND  8.481486e+00
# 1  liquid storage tank, chemicals, organics            GLO  5.478571e-09
#
#       input unit  GWP score  share of cracking GWP (%)  \
# 0       kilogram   1.373930                  71.987363
# 2           unit   0.308175                  16.146891
# 3  kilowatt hour   0.219805                  11.516737
# 1           unit   0.006661                   0.349009
#
#    share of market GWP (%)  rank within market
# 0                36.140770                   1
# 2                 8.106438                   2
# 3                 5.781900                   3
# 1                 0.175218                   4

# %%
# Compare transport technologies on the common functional unit of 1 tonne-kilometre.
# Pipeline is excluded because its premise activity is expressed per kg H2, not per tkm.
TKM_FUNCTIONAL_UNIT = 1.0
TKM_LOCATION_PREFERENCE = ("RER", "EUR", "GLO", "ROW")
TKM_TRANSPORT_TECHNOLOGIES = {
    "Compressed gaseous H2 truck": (
        "transport, hydrogen, gaseous, lorry, unspecified"
    ),
    "Liquid H2 truck": (
        "transport, hydrogen, liquid, lorry, unspecified"
    ),
    "Ammonia tanker — ammonia and MDO": (
        "transport, freight, sea, tanker for liquefied ammonia, ammonia and mdo"
    ),
    "Ammonia tanker — MDO": (
        "transport, freight, sea, tanker for liquefied ammonia, mdo"
    ),
    #"Liquid H2 tanker": (
    #    "transport, freight, sea, tanker for liquefied hydrogen, heavy fuel oil"
    #),
}
TKM_COLORS = {
    "Compressed gaseous H2 truck": "#4C78A8",
    "Liquid H2 truck": "#F28E2B",
    "Ammonia tanker — ammonia and MDO": "#B07AA1",
    "Ammonia tanker — MDO": "#9C755F",
    "Liquid H2 tanker": "#E15759",
}

def select_tkm_transport_activity(activity_name):
    """Select one exact tkm activity with a transparent location preference."""
    normalized_name = stage_analysis._normalized(activity_name)
    candidates = [
        activity for activity in database
        if stage_analysis._normalized(activity.get("name")) == normalized_name
        and stage_analysis._normalized(activity.get("unit")) == "ton kilometer"
    ]
    if not candidates:
        raise LookupError(f"No exact tkm transport activity found for {activity_name!r}.")

    def preference(activity):
        location = str(activity.get("location", "")).upper()
        try:
            location_rank = TKM_LOCATION_PREFERENCE.index(location)
        except ValueError:
            location_rank = len(TKM_LOCATION_PREFERENCE)
        return location_rank, location, str(activity.key)

    selected_activity = sorted(candidates, key=preference)[0]
    return selected_activity, candidates

tkm_comparison_records = []
for technology, activity_name in TKM_TRANSPORT_TECHNOLOGIES.items():
    activity, candidates = select_tkm_transport_activity(activity_name)
    lca = bc.LCA({activity: TKM_FUNCTIONAL_UNIT}, PREMISE_GWP_METHOD)
    lca.lci()
    lca.lcia()
    tkm_comparison_records.append({
        "transport technology": technology,
        "activity name": activity.get("name"),
        "reference product": activity.get("reference product"),
        "selected location": activity.get("location"),
        "available locations": ", ".join(sorted({
            str(candidate.get("location")) for candidate in candidates
        })),
        "unit": activity.get("unit"),
        "premise-GWP per tkm": float(lca.score),
        "database key": activity.key,
    })
    print(f"Finished {technology} ({activity.get('location')})")

transport_gwp_per_tkm_df = pd.DataFrame(tkm_comparison_records)
positive_scores = transport_gwp_per_tkm_df.loc[
    transport_gwp_per_tkm_df["premise-GWP per tkm"] > 0,
    "premise-GWP per tkm",
]
if positive_scores.empty:
    raise ValueError("No positive per-tkm GWP scores were calculated.")
transport_gwp_per_tkm_df["GWP relative to lowest"] = (
    transport_gwp_per_tkm_df["premise-GWP per tkm"] / positive_scores.min()
)
transport_gwp_per_tkm_df = transport_gwp_per_tkm_df.sort_values(
    "premise-GWP per tkm", ascending=False
).reset_index(drop=True)
display(transport_gwp_per_tkm_df)
print(
    "Pipeline is not shown: its distribution activity has a kilogram functional "
    "unit and cannot be converted to tkm without an explicit pipeline distance."
)

fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(
    transport_gwp_per_tkm_df["transport technology"],
    transport_gwp_per_tkm_df["premise-GWP per tkm"],
    color=[
        TKM_COLORS[technology]
        for technology in transport_gwp_per_tkm_df["transport technology"]
    ],
    width=0.7,
)
ax.bar_label(
    bars,
    labels=[
        f"{score:.2e}"
        for score in transport_gwp_per_tkm_df["premise-GWP per tkm"]
    ],
    padding=4,
    fontsize=10,
)
ax.set_ylabel(f"{method_units[PREMISE_GWP_METHOD]} per tkm")
ax.set_xlabel("Transport technology")
ax.set_title("Hydrogen-carrier transport technologies — premise-GWP per tkm")
ax.tick_params(axis="x", rotation=25)
for label in ax.get_xticklabels():
    label.set_horizontalalignment("right")
ax.spines[["top", "right"]].set_visible(False)
ax.set_axisbelow(True)
ax.grid(axis="y", alpha=0.25)
fig.tight_layout()
plt.show()
# Out:
# Finished Compressed gaseous H2 truck (GLO)
# Finished Liquid H2 truck (GLO)
# Finished Ammonia tanker — ammonia and MDO (GLO)
# Finished Ammonia tanker — MDO (GLO)
#                transport technology  \
# 0                   Liquid H2 truck
# 1       Compressed gaseous H2 truck
# 2  Ammonia tanker — ammonia and MDO
# 3              Ammonia tanker — MDO
#
#                                                             activity name  \
# 0                         transport, hydrogen, liquid, lorry, unspecified
# 1                        transport, hydrogen, gaseous, lorry, unspecified
# 2  transport, freight, sea, tanker for liquefied ammonia, ammonia and mdo
# 3              transport, freight, sea, tanker for liquefied ammonia, mdo
#
#                                                         reference product  \
# 0                         transport, hydrogen, liquid, lorry, unspecified
# 1                        transport, hydrogen, gaseous, lorry, unspecified
# 2  transport, freight, sea, tanker for liquefied ammonia, ammonia and mdo
# 3              transport, freight, sea, tanker for liquefied ammonia, mdo
#
#   selected location available locations           unit  premise-GWP per tkm  \
# 0               GLO                 GLO  ton kilometer             0.819192
# 1               GLO                 GLO  ton kilometer             0.678070
# 2               GLO                 GLO  ton kilometer             0.143496
# 3               GLO                 GLO  ton kilometer             0.005027
#
#                                                                                database key  \
# 0  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 27adc2bf3f8941809df91592d422caf9)
# 1  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, 5491f64f2d1d45e0b23a7d9ff257dfed)
# 2  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, e876bc6277f64cfe9d595dadaf880fc6)
# 3  (ecoinvent-3.12-cutoff_SSP2-NDC-remind_2050_05-2_full, a1f7c2ba1cf14bb886f3a31d2f3d8803)
#
#    GWP relative to lowest
# 0              162.960402
# 1              134.887303
# 2               28.545377
# 3                1.000000
# Pipeline is not shown: its distribution activity has a kilogram functional unit and cannot be converted to tkm without an explicit pipeline distance.
